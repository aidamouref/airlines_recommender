# %%
#IMPORT LIBRARIES
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("datasets/cleandf.csv")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## SENTIMENT ANALYSIS

# %%
#NOTE_ THIS IS DONE NOW BY TITLE REVIEW (quickest). It can also be done by body of review but then check why some +1 have low overall!

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon') #lexic for sentiment analyser
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Aida\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
nltk.download("punkt") #to avoid errors
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aida\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
df.TITLE.head()
# Out:
# 0            pretty decent airline
# 1               Not a good airline
# 2     flight was fortunately short
# 3    impossible to check in online
# 4        the support was fantastic
# Name: TITLE, dtype: object

# %%
df.TITLE.tail() #important, take out the name of airlines from the sentiment analysis!
# Out:
# 90003    Wizz Air customer review
# 90004    Wizz Air customer review
# 90005    Wizz Air customer review
# 90006    Wizz Air customer review
# 90007    Wizz Air customer review
# Name: TITLE, dtype: object

# %%
df['TITLE'] = df["TITLE"].astype(str)

# %%
df['TOKENIZREVIEW'] = df.apply(lambda row: nltk.word_tokenize(row['TITLE']), axis=1)

# %%
df.tail()
# Out:
#        Unnamed: 0 AIRLINENAME  CABINTYPE   DATEFLOWN         DATEPUB  \
# 90003       90314    Wizz Air          1  2015-05-01  28th June 2015
# 90004       90315    Wizz Air          1  2015-06-01  22nd June 2015
# 90005       90316    Wizz Air          1  2015-04-01  18th June 2015
# 90006       90317    Wizz Air          1  2015-06-01  16th June 2015
# 90007       90318    Wizz Air          1  2015-02-01  13th June 2015
#
#        ENTERTAINMENTRATING  FOODRATING  GROUNDSERVICERATING  ORIGINCOUNTRY  \
# 90003                    0           0                    2       Slovakia
# 90004                    1           1                    1   UnitedStates
# 90005                    0           0                    2  UnitedKingdom
# 90006                    0           0                    1   UnitedStates
# 90007                    0           1                    1        Romania
#
#        OVERALLSCORE  RECOMMENDED  \
# 90003             8            1
# 90004             1            0
# 90005             1            0
# 90006             1            0
# 90007             1            0
#
#                                                   REVIEW  \
# 90003  If you are going with them, you need to learn ...
# 90004  We went to Ciampino airport 3 hours early and ...
# 90005  I had never heard of Wizz Air before but as th...
# 90006  Very disappointing experience. The airline cha...
# 90007  Wizz Air is hands down the worst airline in al...
#
#                           ROUTE        ORIGIN    DESTINY  SCALE_YN  \
# 90003     Budapest to Barcelona      Budapest  Barcelona         0
# 90004         Rome to Bucharest          Rome  Bucharest         0
# 90005  London Luton to Budapest  London Luton   Budapest         0
# 90006      Budapest to Tel Aviv      Budapest   Tel Aviv         0
# 90007         Budapest to Dubai      Budapest      Dubai         0
#
#        SEATCOMFORTRATING  SERVICERATING      SLUG                     TITLE  \
# 90003                  1              1  wizz-air  Wizz Air customer review
# 90004                  1              2  wizz-air  Wizz Air customer review
# 90005                  2              1  wizz-air  Wizz Air customer review
# 90006                  2              2  wizz-air  Wizz Air customer review
# 90007                  1              1  wizz-air  Wizz Air customer review
#
#        TRAVELLER  PURPOSE  TRIPVERIFIED  VALUERATING  WIFIRATING  \
# 90003          1        1             0            5           0
# 90004          3        1             0            1           1
# 90005          1        1             0            2           0
# 90006          2        1             0            1           0
# 90007          3        1             0            1           0
#
#                                   UNIQUE_ID  LONGDISTANCE  YEAR  \
# 90003  915bc85a-6180-4f7f-b8af-d7241c9a54d5             0  2015
# 90004  78bd246c-bfef-4070-b2b1-fd7b7fe1bf74             1  2015
# 90005  0a8c1827-23c7-4641-89f4-da2c9632f704             0  2015
# 90006  0aa3b03e-1f3c-451e-872a-959aba6bebb6             0  2015
# 90007  a6ed1d97-7983-4369-a5ce-0f229fcd0931             0  2015
#
#                        TOKENIZREVIEW
# 90003  [Wizz, Air, customer, review]
# 90004  [Wizz, Air, customer, review]
# 90005  [Wizz, Air, customer, review]
# 90006  [Wizz, Air, customer, review]
# 90007  [Wizz, Air, customer, review]

# %%
#include all values from airlines and countries to stop words (i.e. avoid neutrality)
airline_stopwords = set(df['AIRLINENAME'].values)
country_stopwords = set(df['ORIGINCOUNTRY'].values)

# %%
airline_stopwords=list(airline_stopwords)
country_stopwords=list(country_stopwords)

# %%
 import nltk
 nltk.download('stopwords')
 from nltk.corpus import stopwords
 #add new words to the list
 new_stopwords = ['and','I','A','And','So','arnt','This','When','It','many','Many','so','cant', 'again','Yes','yes','No','no','These','these','customer service','service', 'customer', 'review', 'customer review', 'airline', 'airlines', 'flight', 'seat', 'seats',  'seat','customer review', '$', '#', '£','check-in', 'check in', 'fly']
 stopwrd = nltk.corpus.stopwords.words('english')
 stopwrd.extend(new_stopwords)
 stopwrd.extend(airline_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aida\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwrd=stopwrd+airline_stopwords+country_stopwords

# %%
stopwrd
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'and',
#  'I',
#  'A',
#  'And',
#  'So',
#  'arnt',
#  'This',
#  'When',
#  'It',
#  'many',
#  'Many',
#  'so',
#  'cant',
#  'again',
#  'Yes',
#  'yes',
#  'No',
#  'no',
#  'These',
#  'these',
#  'customer service',
#  'service',
#  'customer',
#  'review',
#  'customer review',
#  'airline',
#  'airlines',
#  'flight',
#  'seat',
#  'seats',
#  'seat',
#  'customer review',
#  '$',
#  '#',
#  '£',
#  'check-in',
#  'check in',
#  'fly',
#  'Philippine Airlines',
#  'Joon',
#  'Ariana Afghan Airlines',
#  'Lynx Air',
#  'Air Madagascar',
#  'Aegean Airlines',
#  'Jetstar Airways',
#  'Firefly',
#  'Pakistan Intl Airlines',
#  'AirAsia Zest',
#  'AnadoluJet',
#  'Passion Air',
#  'Egyptair',
#  'bmi Regional',
#  'Onur Air',
#  'MEGA Maldives Airlines',
#  'Thomas Cook Airlines',
#  'Evelop Airlines',
#  'Citilink',
#  'Copa Airlines',
#  'Transaero Airlines',
#  'Sunwing Airlines',
#  'Far Eastern Air Transport',
#  'QantasLink',
#  'Canaryfly',
#  'Aurigny Air',
#  'US-Bangla Airlines',
#  'Danish Air Transport',
#  'Rhein-Neckar Air',
#  'SkyWork Airlines',
#  'flydubai',
#  'TUS Airways',
#  'Air Juan',
#  'Israir Airlines',
#  'Pan Pacific Airlines',
#  'Iberia Express',
#  'Openskies',
#  'Southwest Airlines',
#  'Croatia Airlines',
#  'Go First',
#  'Aero VIP',
#  'Insel Air',
#  'Brussels Airlines',
#  'Kam Air',
#  'Mann Yadanarpon Airlines',
#  "T'Way Air",
#  'Dimonim Air',
#  'Air Tanzania',
#  'TUI Airways',
#  'Africa World Airlines',
#  'Peach Aviation',
#  'American Eagle',
#  'Kenya Airways',
#  'Ethiopian Airlines',
#  'ANA All Nippon Airways',
#  'Maya Island Air',
#  'Helvetic Airways',
#  'Malindo Air',
#  'Nature Air',
#  'Binter Canarias',
#  'Cebu Pacific',
#  'Spirit Airlines',
#  'SilkAir',
#  'Air Mauritius',
#  'Fiji Airways',
#  'Tibet Airlines',
#  'Maldivian',
#  'Solomon Airlines',
#  'Bangkok Airways',
#  'Air Greenland',
#  'Air Zimbabwe',
#  'Cambodia Angkor Air',
#  'AirAsia',
#  'Air KBZ',
#  'LIAT',
#  'Asiana Airlines',
#  'Arkefly',
#  'Air Canada',
#  'PenAir',
#  'Caribbean Airlines',
#  'Yangon Airways',
#  'Cathay Pacific Airways',
#  'Hainan Airlines',
#  'Auric Air',
#  'Ellinair',
#  'Vistara',
#  'Eastern Airways',
#  'Nile Air',
#  'Jordan Aviation',
#  'Bhutan Airlines',
#  'Royal Jordanian Airlines',
#  'Viva Air',
#  'ASKY Airlines',
#  'Safarilink',
#  'Japan Airlines',
#  'Novoair',
#  'SA Express',
#  'Mandarin Airlines',
#  'Norse Atlantic Airways',
#  'Privilege Style',
#  'Andes Líneas Aéreas',
#  'Precision Air',
#  'Bulgaria Air',
#  'Thomas Cook Airlines Scandinavia',
#  'Aigle Azur',
#  'Flair Airlines',
#  'HOP!',
#  'Condor Airlines',
#  'Manta Air',
#  'Jetblue Airways',
#  'Laudamotion',
#  'Salam Air',
#  'Air India',
#  'NAM Air',
#  'Georgian Airways',
#  'Rossiya Airlines',
#  'Tunisair',
#  'Cape Air',
#  'SVG Air',
#  'Cobalt',
#  'Red Wings Airlines',
#  'LAN Peru',
#  'TACA Airlines',
#  'Atlantic Airways',
#  'WestJet Airlines',
#  'Xiamen Airlines',
#  'Qantas Airways',
#  'Trigana Air',
#  'Frontier Airlines',
#  'Jetstar Asia',
#  'FlyArystan',
#  'Interjet',
#  'Emirates',
#  'Montenegro Airlines',
#  'Swiss Intl Air Lines',
#  'China Airlines',
#  'Armenia Air Company',
#  'SATA Air Azores',
#  'Air Nostrum',
#  'Felix Airways',
#  'AB Aviation',
#  'Volaris',
#  'flybe',
#  'Vanilla Air',
#  'PAL Express',
#  'Motor Sich Airlines',
#  'Finnair',
#  'Cubana Airlines',
#  'Aer Lingus',
#  'Air Italy',
#  'LAN Airlines',
#  'El Al Israel Airlines',
#  'Libyan Airlines',
#  'Mango Airlines',
#  'Air Costa',
#  'MAYAir',
#  'Jet Airways',
#  'Nordica',
#  'British Airways',
#  'Yeti Airlines',
#  'Korean Air',
#  'Intercaribbean Airways',
#  'Kan Air',
#  'Sichuan Airlines',
#  'Air France',
#  'Avior Airlines',
#  'UP by El Al',
#  'Air Djibouti',
#  'Sun Country Airlines',
#  'Air Namibia',
#  'Iran Air',
#  'Dragonair',
#  'Amaszonas',
#  'PAWA Dominicana',
#  'Swoop',
#  'Nauru Airlines',
#  'Cathay Dragon',
#  'LAN Colombia',
#  'TAR Aerolineas',
#  'Aeromexico',
#  'Smartavia',
#  'Madagasikara Airways',
#  'Darwin Airline',
#  'Royal Brunei Airlines',
#  'Azerbaijan Airlines',
#  'Blue Panorama Airlines',
#  'TAG Airlines',
#  'Avianca Ecuador',
#  'Thai Lion Air',
#  'FlySafair',
#  'airBaltic',
#  'Bamboo Airways',
#  'China Eastern Airlines',
#  'Wingo',
#  'SriLankan Airlines',
#  'Hi Fly',
#  'Buddha Air',
#  'Peruvian Airlines',
#  'Air Busan',
#  "Air Cote d'Ivoire",
#  'Titan Airways',
#  'Turkish Airlines',
#  'SmartWings',
#  'AirAsia India',
#  'Nordic Regional Airlines',
#  'Air China',
#  'Mahan Air',
#  'Jetstar Japan',
#  'American Airlines',
#  'HK Express',
#  'Badr Airlines',
#  "Air North Yukon's Airline",
#  'Edelweiss Air',
#  'Corendon Airlines',
#  'Sun-Air',
#  'South African Airways',
#  'Star Peru',
#  'Bassaka Air',
#  'Germania Airline',
#  'Regional Express',
#  'Air New Zealand',
#  'Island Air',
#  'Cambodia Bayon Airlines',
#  'ITA Airways',
#  'NordStar',
#  'Pegasus Airlines',
#  'Zambia Airways',
#  'Horizon Air',
#  'Blu-express',
#  'Sky Airline',
#  'Passaredo',
#  'Wings Air',
#  'EVA Air',
#  'Tigerair Australia',
#  'TAAG Angola Airlines',
#  'BA CityFlyer',
#  'Suparna Airlines',
#  'Cambodia Airways',
#  'Aircalin',
#  'Surinam Airways',
#  'Akasa Air',
#  'Blue Air',
#  'LC Perú',
#  'Air Seychelles',
#  'Transavia',
#  'Beijing Capital Airlines',
#  'Eurowings',
#  'Garuda Indonesia',
#  'Skybus',
#  'Gol Transportes Aéreos',
#  'AirAsia Philippines',
#  'Greater Bay Airlines',
#  'AirSWIFT',
#  'Lufthansa',
#  'Hawaiian Airlines',
#  'Skytrans Airlines',
#  'Jin Air',
#  'Azul Airlines',
#  'AirAsia X',
#  'TAP Portugal',
#  'Golden Myanmar Airlines',
#  'Wizz Air',
#  'Vietnam Airlines',
#  'Air Pegasus',
#  'Ural Airlines',
#  'US Airways',
#  'Iran Aseman Airlines',
#  'Kish Airlines',
#  'CityJet',
#  'Ukraine International',
#  'Aerolineas Argentinas',
#  'Silver Airways',
#  'United Airlines',
#  'Wamos Air',
#  'SereneAir',
#  'BH Air',
#  'LOT Polish Airlines',
#  'euroAtlantic Airways',
#  'Hunnu Air',
#  'Boliviana de Aviacion',
#  'Iberia',
#  'Jeju Air',
#  'Regent Airways',
#  'Air Arabia',
#  'Atlasglobal',
#  'Himalaya Airlines',
#  'TUIfly Nordic',
#  'Oman Air',
#  'Batik Air',
#  'SATENA',
#  'Thai Smile Airways',
#  'Alaska Airlines',
#  'Santa Barbara Airlines',
#  'Seaborne Airlines',
#  'Air Malta',
#  'Wideroe',
#  'Cyprus Airways',
#  'Tame Línea Aérea Del Ecuador',
#  'Freebird Airlines',
#  'Tigerair',
#  'Nok Air',
#  'HiSky',
#  'Druk Air',
#  'GoAir',
#  'Comair',
#  'Corsair',
#  'TAROM Romanian',
#  'Primera Air',
#  'VivaAerobús',
#  'S7 Siberia Airlines',
#  'Mauritania Airlines',
#  'Malawian Airlines',
#  'Tropic Air Belize',
#  'Safi Airways',
#  'VietJet Air',
#  'Volotea',
#  'Aeromar',
#  'ViaAir',
#  'Saudi Arabian Airlines',
#  'Skymark Airlines',
#  'VivaColombia',
#  'Boutique Air',
#  'SkyUp Airlines',
#  'TUIfly',
#  'ZIPAIR',
#  'Nordwind Airlines',
#  'Porter Airlines',
#  'China United Airlines',
#  'FMI Air',
#  'Virgin Atlantic',
#  'Juneyao Airlines',
#  'Jetairfly',
#  'Virgin Australia',
#  'XL Airways France',
#  'Germanwings',
#  'Olympic Air',
#  'Lion Air',
#  'Air Koryo',
#  'Canadian North',
#  'Scoot',
#  'Utair Aviation',
#  'VLM Airlines',
#  'Mihin Lanka',
#  'JetSmart',
#  'SCAT Airlines',
#  'Small Planet Airlines',
#  'Air Corsica',
#  'Qazaq Air',
#  'Pobeda Airlines',
#  'SkyWest Airlines',
#  'Winair',
#  'China Southern Airlines',
#  'Estonian Air',
#  'Uganda Airlines',
#  'Avelo Airlines',
#  'IndiGo',
#  'Somon Air',
#  'Etihad Airways',
#  'Lubeck Air',
#  'NokScoot',
#  'SATA International',
#  'Sky Express Airlines',
#  'Alliance Air',
#  'Middle East Airlines',
#  'Air Algerie',
#  'Shandong Airlines',
#  'TACV Cabo Verde Airlines',
#  'Shenzhen Airlines',
#  'WOW air',
#  'Voyage Air',
#  'Turkmenistan Airlines',
#  'Dynamic International Airways',
#  'Thai Airways',
#  'Breeze Airways',
#  'Air Vanuatu',
#  'Central Mountain Air',
#  'BoraJet',
#  'Petroleum Air Services',
#  'Jetstar Pacific',
#  'Spring Airlines',
#  'Pacific Airlines',
#  'Air Dolomiti',
#  'Kuwait Airways',
#  'Lao Airlines',
#  'Air Caraibes',
#  'MIAT Mongolian Airlines',
#  'Delta Air Lines',
#  'Avianca Brazil',
#  'Uzbekistan Airways',
#  'Hong Kong Airlines',
#  'Air Berlin',
#  'Air Botswana',
#  'Royal Air Maroc',
#  'Monarch Airlines',
#  'Kulula',
#  'Thomas Cook Airlines Belgium',
#  'World2Fly',
#  'Virgin America',
#  'Adria Airways',
#  'Air Iceland Connect',
#  'V Air',
#  'Easyfly',
#  'KLM Royal Dutch Airlines',
#  'Air Astana',
#  'fastjet',
#  'TAME',
#  'Air Serbia',
#  'Tigerair Taiwan',
#  'SAS Scandinavian',
#  'Air Macau',
#  'Super Air Jet',
#  'French Bee',
#  'Air Moldova',
#  'JetsuiteX',
#  'Air Austral',
#  'Fly540.com',
#  'Austrian Airlines',
#  'SunExpress',
#  'Air Burkina',
#  'Singapore Airlines',
#  'Yakutia Airlines',
#  'Arik Air',
#  'Air Tahiti Nui',
#  'Airlink',
#  'Allegiant Air',
#  'Lao Skyway',
#  'Sriwijaya Air',
#  'Jazeera Airways',
#  'Ravn Alaska',
#  'Thai AirAsia',
#  'StarFlyer',
#  'Biman Bangladesh Airlines',
#  'Orient Thai Airlines',
#  'SpiceJet',
#  'EWA Air',
#  'Meridiana',
#  'Air Niugini',
#  'LATAM Airlines',
#  'Air Transat',
#  'easyJet',
#  'ATA Airlines',
#  'Air Canada rouge',
#  'Azur Air Germany',
#  'Jet2.com',
#  'Level',
#  'Omni Air International',
#  'Qatar Airways',
#  'CemAir',
#  'JC International Airlines',
#  'Air Cairo',
#  'Eastern Airlines',
#  'Air Europa',
#  'Alitalia',
#  'Lucky Air',
#  'Bluebird Airways',
#  'Coastal Aviation',
#  'Icelandair',
#  'Nouvelair',
#  'Shaheen Air',
#  'Ernest Airlines',
#  'Tailwind Airlines',
#  'Buta Airways',
#  'SmartLynx Airlines',
#  'Jazz',
#  'Myanmar Airways',
#  'Rex Airlines',
#  'Air Antilles',
#  'AeroItalia',
#  'Nepal Airlines',
#  'Grand Cru Airlines',
#  'Luxair',
#  'Loganair',
#  'Air Rarotonga',
#  'FLYONE',
#  'Norwegian',
#  'Vueling Airlines',
#  'Blue1',
#  'Cayman Airways',
#  'Belavia',
#  'Ryanair',
#  'Ultra Air',
#  'Aeroflot Russian Airlines',
#  'LAM Mozambique',
#  'PLAY',
#  'Flynas',
#  'Mokulele Airlines',
#  'Myanmar National Airlines',
#  'Bahamasair',
#  'Airnorth',
#  'Tianjin Airlines',
#  'airblue',
#  'TAM Airlines',
#  'flyadeal',
#  'KD Air',
#  'Sansa Airlines',
#  'Eastar Jet',
#  'Nordavia',
#  'Camair-Co',
#  'Blue Islands',
#  'Mack Air',
#  'Rwandair',
#  'La Compagnie',
#  'Air Panama',
#  'Arkia Israeli Airlines',
#  'Air India Express',
#  'CSA Czech Airlines',
#  'Malaysia Airlines',
#  'Thomson Airways',
#  'Avianca',
#  'Alliance Airlines',
#  'Shanghai Airlines',
#  'Iraqi Airways',
#  'NIKI',
#  'Gulf Air',
#  'Philippine Airlines',
#  'Joon',
#  'Ariana Afghan Airlines',
#  'Lynx Air',
#  'Air Madagascar',
#  'Aegean Airlines',
#  'Jetstar Airways',
#  'Firefly',
#  'Pakistan Intl Airlines',
#  'AirAsia Zest',
#  'AnadoluJet',
#  'Passion Air',
#  'Egyptair',
#  'bmi Regional',
#  'Onur Air',
#  'MEGA Maldives Airlines',
#  'Thomas Cook Airlines',
#  'Evelop Airlines',
#  'Citilink',
#  'Copa Airlines',
#  'Transaero Airlines',
#  'Sunwing Airlines',
#  'Far Eastern Air Transport',
#  'QantasLink',
#  'Canaryfly',
#  'Aurigny Air',
#  'US-Bangla Airlines',
#  'Danish Air Transport',
#  'Rhein-Neckar Air',
#  'SkyWork Airlines',
#  'flydubai',
#  'TUS Airways',
#  'Air Juan',
#  'Israir Airlines',
#  'Pan Pacific Airlines',
#  'Iberia Express',
#  'Openskies',
#  'Southwest Airlines',
#  'Croatia Airlines',
#  'Go First',
#  'Aero VIP',
#  'Insel Air',
#  'Brussels Airlines',
#  'Kam Air',
#  'Mann Yadanarpon Airlines',
#  "T'Way Air",
#  'Dimonim Air',
#  'Air Tanzania',
#  'TUI Airways',
#  'Africa World Airlines',
#  'Peach Aviation',
#  'American Eagle',
#  'Kenya Airways',
#  'Ethiopian Airlines',
#  'ANA All Nippon Airways',
#  'Maya Island Air',
#  'Helvetic Airways',
#  'Malindo Air',
#  'Nature Air',
#  'Binter Canarias',
#  'Cebu Pacific',
#  'Spirit Airlines',
#  'SilkAir',
#  'Air Mauritius',
#  'Fiji Airways',
#  'Tibet Airlines',
#  'Maldivian',
#  'Solomon Airlines',
#  'Bangkok Airways',
#  'Air Greenland',
#  'Air Zimbabwe',
#  'Cambodia Angkor Air',
#  'AirAsia',
#  'Air KBZ',
#  'LIAT',
#  'Asiana Airlines',
#  'Arkefly',
#  'Air Canada',
#  'PenAir',
#  'Caribbean Airlines',
#  'Yangon Airways',
#  'Cathay Pacific Airways',
#  'Hainan Airlines',
#  'Auric Air',
#  'Ellinair',
#  'Vistara',
#  'Eastern Airways',
#  'Nile Air',
#  'Jordan Aviation',
#  'Bhutan Airlines',
#  'Royal Jordanian Airlines',
#  'Viva Air',
#  'ASKY Airlines',
#  'Safarilink',
#  'Japan Airlines',
#  'Novoair',
#  'SA Express',
#  'Mandarin Airlines',
#  'Norse Atlantic Airways',
#  'Privilege Style',
#  'Andes Líneas Aéreas',
#  'Precision Air',
#  'Bulgaria Air',
#  'Thomas Cook Airlines Scandinavia',
#  'Aigle Azur',
#  'Flair Airlines',
#  'HOP!',
#  'Condor Airlines',
#  'Manta Air',
#  'Jetblue Airways',
#  'Laudamotion',
#  'Salam Air',
#  'Air India',
#  'NAM Air',
#  'Georgian Airways',
#  'Rossiya Airlines',
#  'Tunisair',
#  'Cape Air',
#  'SVG Air',
#  'Cobalt',
#  'Red Wings Airlines',
#  'LAN Peru',
#  'TACA Airlines',
#  'Atlantic Airways',
#  'WestJet Airlines',
#  'Xiamen Airlines',
#  'Qantas Airways',
#  'Trigana Air',
#  'Frontier Airlines',
#  'Jetstar Asia',
#  'FlyArystan',
#  'Interjet',
#  'Emirates',
#  'Montenegro Airlines',
#  'Swiss Intl Air Lines',
#  'China Airlines',
#  'Armenia Air Company',
#  'SATA Air Azores',
#  'Air Nostrum',
#  'Felix Airways',
#  'AB Aviation',
#  'Volaris',
#  'flybe',
#  'Vanilla Air',
#  'PAL Express',
#  'Motor Sich Airlines',
#  'Finnair',
#  'Cubana Airlines',
#  'Aer Lingus',
#  'Air Italy',
#  'LAN Airlines',
#  'El Al Israel Airlines',
#  'Libyan Airlines',
#  'Mango Airlines',
#  'Air Costa',
#  'MAYAir',
#  'Jet Airways',
#  'Nordica',
#  'British Airways',
#  'Yeti Airlines',
#  'Korean Air',
#  'Intercaribbean Airways',
#  'Kan Air',
#  'Sichuan Airlines',
#  'Air France',
#  'Avior Airlines',
#  'UP by El Al',
#  'Air Djibouti',
#  'Sun Country Airlines',
#  'Air Namibia',
#  'Iran Air',
#  'Dragonair',
#  'Amaszonas',
#  'PAWA Dominicana',
#  'Swoop',
#  'Nauru Airlines',
#  'Cathay Dragon',
#  'LAN Colombia',
#  'TAR Aerolineas',
#  'Aeromexico',
#  'Smartavia',
#  'Madagasikara Airways',
#  'Darwin Airline',
#  'Royal Brunei Airlines',
#  'Azerbaijan Airlines',
#  'Blue Panorama Airlines',
#  'TAG Airlines',
#  'Avianca Ecuador',
#  'Thai Lion Air',
#  'FlySafair',
#  'airBaltic',
#  'Bamboo Airways',
#  'China Eastern Airlines',
#  'Wingo',
#  'SriLankan Airlines',
#  'Hi Fly',
#  'Buddha Air',
#  'Peruvian Airlines',
#  'Air Busan',
#  "Air Cote d'Ivoire",
#  'Titan Airways',
#  'Turkish Airlines',
#  'SmartWings',
#  'AirAsia India',
#  'Nordic Regional Airlines',
#  'Air China',
#  'Mahan Air',
#  'Jetstar Japan',
#  'American Airlines',
#  'HK Express',
#  'Badr Airlines',
#  "Air North Yukon's Airline",
#  'Edelweiss Air',
#  'Corendon Airlines',
#  'Sun-Air',
#  'South African Airways',
#  'Star Peru',
#  'Bassaka Air',
#  'Germania Airline',
#  'Regional Express',
#  'Air New Zealand',
#  'Island Air',
#  'Cambodia Bayon Airlines',
#  'ITA Airways',
#  'NordStar',
#  'Pegasus Airlines',
#  'Zambia Airways',
#  'Horizon Air',
#  'Blu-express',
#  'Sky Airline',
#  'Passaredo',
#  'Wings Air',
#  'EVA Air',
#  'Tigerair Australia',
#  'TAAG Angola Airlines',
#  'BA CityFlyer',
#  'Suparna Airlines',
#  'Cambodia Airways',
#  'Aircalin',
#  'Surinam Airways',
#  'Akasa Air',
#  'Blue Air',
#  'LC Perú',
#  'Air Seychelles',
#  'Transavia',
#  'Beijing Capital Airlines',
#  'Eurowings',
#  'Garuda Indonesia',
#  'Skybus',
#  'Gol Transportes Aéreos',
#  'AirAsia Philippines',
#  'Greater Bay Airlines',
#  'AirSWIFT',
#  'Lufthansa',
#  'Hawaiian Airlines',
#  'Skytrans Airlines',
#  'Jin Air',
#  'Azul Airlines',
#  'AirAsia X',
#  'TAP Portugal',
#  'Golden Myanmar Airlines',
#  'Wizz Air',
#  'Vietnam Airlines',
#  'Air Pegasus',
#  'Ural Airlines',
#  'US Airways',
#  'Iran Aseman Airlines',
#  'Kish Airlines',
#  'CityJet',
#  ...]

# %%
df["filtered_tokens"] = df['TOKENIZREVIEW'] .apply(lambda x: ' '.join([word for word in x if word not in (stopwrd)]))

# %%
df["filtered_tokens"]=df["filtered_tokens"].replace(',','', regex=True)

# %%
#ps=PorterStemmer()

# %%
#df["stemmed_tokens"]=[ps.stem(word)for word in df["filtered_tokens"] ]

# %%
df["filtered_tokens"]
# Out:
# 0                  pretty decent
# 1                       Not good
# 2              fortunately short
# 3        impossible check online
# 4              support fantastic
#                   ...
# 90003                   Wizz Air
# 90004                   Wizz Air
# 90005                   Wizz Air
# 90006                   Wizz Air
# 90007                   Wizz Air
# Name: filtered_tokens, Length: 90008, dtype: object

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Aida\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer=WordNetLemmatizer()
lemmatized_tokens=[lemmatizer.lemmatize(token, pos="v") for token in df.filtered_tokens]
lemmatized_tokens
# Out:
# ['pretty decent',
#  'Not good',
#  'fortunately short',
#  'impossible check online',
#  'support fantastic',
#  'pilot nice',
#  'fun unique retro-experience',
#  'never Adria',
#  'ruined last days holidays',
#  'Had bad experience',
#  'worse budget',
#  'book another company',
#  'combined two flights',
#  'crew nice',
#  'Very bad experience overall',
#  'bad',
#  'overall poor',
#  'Would',
#  'unpleasant experience',
#  'Flight comfortable',
#  'delayed 2 hours',
#  'ashamed operations',
#  'Two nice short flights',
#  'extremely bad',
#  'never',
#  "ca n't remember delay",
#  'quite comfortable',
#  'nice comfortable flights',
#  'great surprise',
#  'value money experience',
#  'fleet tired outdated',
#  'underwhelming unimpressive',
#  'different experiences',
#  'staff pleasant enough',
#  'Adria take criticism well',
#  'Clean fresh aircraft',
#  'job',
#  'nice professional',
#  'cabin staff rather absent',
#  'never flying',
#  'similar low cost',
#  'happened last months',
#  'friendly helpful staff',
#  'onboard poor',
#  'low cost',
#  'staff friendly unobtrusive',
#  'never use',
#  'never use',
#  'never',
#  'bad',
#  'strongly advise',
#  'nothing resolved yet',
#  'Incompetent unfriendly',
#  'excellent',
#  'friendly staff',
#  'unclean  unsafe  unpunctual unconcerned',
#  'Needs hold accountable actions',
#  'They never time',
#  'never',
#  'worth cheaper fare',
#  'cancelled three times',
#  'use',
#  'call centre shocking',
#  'An excellent',
#  'simply worth',
#  'Do recommend',
#  'changing 3 letters cost 80EUR',
#  'Worst experienced',
#  'could smile bit',
#  'Worst experience ever !',
#  'Definitely last time',
#  'contact',
#  'tend leave time early',
#  "still n't received money",
#  'disgusted never',
#  'refund paid 5 months',
#  'worst ever flown',
#  'aircraft good condition',
#  'last time flying',
#  'pleasantly surprised',
#  'generally unfriendly',
#  'avoid costs',
#  'Awful !',
#  'told us would wait 8 hours',
#  'received penny',
#  'still reimbursement even reply',
#  'nothing approached business standards',
#  'tickets cancelled',
#  'comfortable economy',
#  'never book',
#  'update name initials name',
#  '8 hours waiting',
#  'Nice experience',
#  'plane clean',
#  'Aircrafts outdated worn',
#  'plane looked felt dated worn',
#  'provided mere basics',
#  'Asked move emergency row',
#  'Low-end bargain price',
#  'ship fragile items',
#  'action blatantly robbery',
#  'Avoid !',
#  'Nice plane  welcoming cabin crew',
#  'Austral flights better',
#  "One dysfunctional organisations ''",
#  'attempted trip back horrible',
#  "worst 've come across",
#  'happy',
#  'certainly',
#  'complaints whatsoever',
#  'brand-new clean airplane',
#  'Flight attendants friendly',
#  'expect friendly',
#  'The worst kind',
#  'one worst flew',
#  'reasonable experience',
#  'cabin staff polite',
#  'terrible',
#  'worst experience ever',
#  'nice seating  good',
#  'food poor',
#  'Aerolineas Argentinas',
#  'utter pandemonium chaos',
#  'Flights went well punctual',
#  'stay away long haul',
#  'The dirty airplane',
#  'would never recommend',
#  'narrow ever seen',
#  'assistance passengers',
#  'get disapproving reply',
#  'average',
#  'attendants friendly',
#  'Very bad',
#  'checked luggage lost',
#  'onboard excellent',
#  'Aircraft old dirty',
#  'constant maintenance issues',
#  'disgust',
#  'pleasant relaxed',
#  'biggest criticism',
#  'think twice',
#  'good',
#  'overall pleased',
#  'business class old',
#  'My luggage come',
#  'Excellent',
#  'Very good',
#  'bad',
#  'staff mixed bunch',
#  'good',
#  'in-flight usually good',
#  'never',
#  'Aerolineas Argentinas',
#  'Aerolineas Argentinas',
#  'aircraft old dirty',
#  'Air Algerie',
#  'Air Algerie',
#  'Air Algerie',
#  'travel Russia receive refund',
#  'RTPCR required children age 5',
#  'waiting refund last 2.5 years',
#  'felt rushed unpolished',
#  'Best Russia',
#  'cabin crew outstanding',
#  'whole ticket cancelled',
#  "proceed refund ''",
#  'communication support ground staff',
#  'Thoroughly recommended',
#  'unpleasant',
#  'leg room bad',
#  'Overall  okay experience',
#  'professional efficient crew',
#  'lines Moscow airport long',
#  'entirely satisfactory',
#  'missed connection',
#  'really bad',
#  'give luggage',
#  'shambolic',
#  '’ recommend',
#  'Horrible experience Sheremetyevo Airport',
#  'provided refund',
#  'use e-voucher',
#  'refused provide compensation',
#  'denied boarding COVID test',
#  'Very bad attitude !',
#  'We pleasantly surprised',
#  'keep stalling',
#  'worst experience',
#  'great little',
#  'delayed reason',
#  'careless handling belongings',
#  'expect better behavior',
#  'carry-on bag restrictions ridiculous',
#  'never recommend',
#  'almost 10 months refund',
#  'The extremely poor',
#  'beyond competition European carriers',
#  'refunding cancelled tickets',
#  'disappoint',
#  'crew outstanding',
#  'consider flying',
#  'forced pay extra luggage',
#  'easy process way',
#  'disappointing experience !',
#  'soft product amazing',
#  'let registration',
#  'keep saying refund processed',
#  'refunded fully ticket costs',
#  'wait 3 years refund',
#  'Flight officially canceled',
#  'Really disappointing',
#  'care clients',
#  'horrendous experience',
#  'check carry',
#  'offer use voucher',
#  'really liked',
#  'They bad pillow',
#  'never',
#  'Stewardesses good',
#  'asked money water',
#  'one worst used',
#  'rules made grab travelers money',
#  'even acknowledge receiving',
#  "n't want anyone suffer like",
#  'positive experience',
#  'aircraft terrible shape',
#  'welcome',
#  'Fantastic services',
#  'recommend highly',
#  'Cabin crews pleasant working hard',
#  'thank enough',
#  'like',
#  'Really atrocious',
#  'Worst everything',
#  'journey postponed three times',
#  'Only last resort',
#  'consistent letting passengers',
#  'worst travel experience',
#  'closed counter 90 min prior',
#  'problems',
#  'unfriendly',
#  'gave value money',
#  'laptop backpack bulky',
#  'bag 3cm large',
#  "n't give food",
#  'refund cancellation',
#  'Staff arrogant',
#  'refund canceled ticket',
#  'truthful us',
#  'know',
#  'Great value budget',
#  'efficient excellent',
#  "n't got repayment",
#  'Not single goodwill action',
#  'tried change meal',
#  'suitcase also broken',
#  'smiling attentive cabin crew',
#  'allowed change',
#  'charged insurance select',
#  'Worst ever used',
#  'Worst experience ever',
#  'horrible life',
#  '’ refund/cancellation policy',
#  'disaster',
#  "n't aerobridge",
#  'appears top',
#  'staff incredible',
#  'run !',
#  'amazing experience',
#  'lounge priority check',
#  '’ received yet answer',
#  'exceptional',
#  'cancel booking refund',
#  'strongly recommend Aeroflot',
#  'pure disaster',
#  'adequate snack provided',
#  'Very pathetic',
#  'Zero care passengers',
#  'worst travel experience',
#  'Very bad experience2',
#  'one best budget',
#  'Thoroughly enjoyed',
#  'Keep good work Air Astana',
#  'waiting refund 3 months',
#  'Service excellent',
#  'return journey equally enjoyable',
#  'seldom see good like',
#  'Aeroflot improved lot',
#  'staff relatively unfriendly',
#  'allow select',
#  'Terrible arrival',
#  '’ let us get inside',
#  'unaware luggage lost procedure',
#  'refused reimburse',
#  'Really bad experience',
#  'refused refund',
#  'trip quite difficult',
#  'pleasant crew',
#  'inattentive rude',
#  'Awful experience',
#  'good',
#  'staff extremely rude unhelpful',
#  "Do ''",
#  'never travel never',
#  'robust high-quality product',
#  'time  good food comfort',
#  'stalled 2 hours without announcements',
#  'charge carry luggage',
#  'documentation refused',
#  'Bad',
#  'seem care passenger rights',
#  'refund policy',
#  'horrendous',
#  'Seats comfortable',
#  'one best experiences',
#  'billed R1800 hand luggage bag',
#  '1 kg checked luggage',
#  'pay receive',
#  "Not worth stress ''",
#  'Never',
#  'Terrible',
#  'exceeded expectations',
#  'never forget kindness',
#  'Leg room good',
#  'stood line least 50 minutes',
#  'forced buy new ticket',
#  'pirate',
#  'refund nowhere seen',
#  'shocked unprofessionalism',
#  'avoid joke company',
#  'model seems lying cheating',
#  'express deep gratitude',
#  'apologetic delay',
#  'total chaos',
#  'personnel professional attentive',
#  'extremely unprofessional',
#  'terrible dysfunctional',
#  "FA 's Flight 616 nasty",
#  'someone else !',
#  'refund',
#  'avoid costs',
#  'wear name tag',
#  'Never book',
#  'credit cards rejected',
#  'change',
#  'Very pleasant staff',
#  'one best flights',
#  "n't get money back",
#  'get visa 2 weeks later',
#  'staff attentive',
#  'another pleasant surprise',
#  'rude extremely unhelpful',
#  'answer inquiries',
#  'never use',
#  'internet  screen front',
#  'Pathetic',
#  'would go way Air Astana',
#  'friendly professional',
#  'Cabin crew training',
#  '4 Star experience',
#  'Attitude terrible',
#  'uncomfortable',
#  'Just disgusting',
#  'really bad experience',
#  'Crew friendly helpful',
#  'Please keep excellent work',
#  'kept high standards',
#  'experience anything pleasant',
#  'The ground crew poor',
#  'deception  lies lack communication',
#  'The worst ever',
#  'Delay 4 hours',
#  'extremely uncomfortable',
#  "'ve gone downhill ''",
#  'online booking joke',
#  "announcement spoken rapidly ''",
#  'value',
#  'Absolutely shocking',
#  'good',
#  'pay 550 Euro new',
#  'offer real business class product',
#  'excellent attention',
#  'miss',
#  'never travel',
#  'Don ’ use !',
#  "could n't recommend Air Arabia",
#  'told departed',
#  'overcharged 60 euros airport',
#  "children 's food came baby food",
#  'Food perfect',
#  'never come back blanket',
#  'Excellent economy',
#  'best option region',
#  'expect',
#  'Never flying',
#  'recommend',
#  'AeroMexico complete scam',
#  'Extremely bad',
#  'refused laptop small carry',
#  'In Flight Service nice',
#  'crew friendly',
#  'pay checks overweight 8kg',
#  'wanted change ticket',
#  'delayed 5.5 hours',
#  'flights comfortable',
#  'cheap low profile',
#  'Scam',
#  'never Aer Lingus',
#  'low-cost basic experience',
#  'FAs helpful firm',
#  'Absolutely recommended',
#  'use November 2020 lose',
#  'handled poorly',
#  'luggage arrive',
#  'compliment thank Aeroflot',
#  'strongly recommend Aeroflot',
#  'never encountered incompetent',
#  'absolutely zero rights',
#  'Staff pleasant',
#  "could n't care less",
#  'impression great',
#  'nice experience',
#  'Consistency ground',
#  'nightmare trying confirm cancellations',
#  'perfect meal way',
#  'never',
#  '',
#  'compensation food accommodation',
#  "would n't recommend flying",
#  'crew friendly helpful',
#  'fee cancel 45€/ticket',
#  'Zero',
#  'loyalty loyal clients',
#  'Super small space',
#  'crew friendly professional',
#  'unprofessional unethical',
#  'shockingly bad',
#  'notorious losing people ’ luggage',
#  'Never Aer Lingus',
#  "n't luggage",
#  'terrible treat customers',
#  'ridiculously cheap',
#  'got Premium Economy',
#  'try avoid terrible',
#  'response Aeroflot',
#  'luggage arrive three days',
#  'None 4 suitcases arrived',
#  'idea luggage',
#  'charge laptop weight',
#  'hand luggage really ridiculous',
#  'better expected',
#  'crew friendly & efficient',
#  'good',
#  'cabin crew professional',
#  'modern  well appointed planes',
#  'All flights time',
#  'fair poor experience',
#  'nothing refund',
#  'suggest another',
#  'told standby passenger',
#  'Very poor',
#  'Never flying',
#  'professional cabin crew',
#  'could easily avoided',
#  "still n't received refund",
#  "Would n't",
#  '’ care less customers',
#  'avoid Aer Lingus costs',
#  'Extremely sketchy',
#  'improvements made',
#  'never Air Caraïbes',
#  'received schedule change',
#  'refused refund money',
#  'overall positive experience',
#  'beyond bad',
#  'said business class full',
#  'still ’ suitcase',
#  'enjoy',
#  '',
#  '200 riyals fine baggage',
#  'Absolute disaster',
#  'nobody let us know cancellation',
#  'way expected',
#  "n't able give answer",
#  'aircraft new clean',
#  'solid experience',
#  '',
#  'told ticket paid',
#  'ever going',
#  'worse budget/low-cost',
#  'cancel',
#  'get support something goes wrong',
#  'One best apps tried far !',
#  'My bag delayed',
#  'simply got worse',
#  'Flight delayed multiple times',
#  'Uncomfortable small leg room',
#  'refused issue refund',
#  'cabin crew awful',
#  'Service onboard good',
#  'rude',
#  'bad experience .',
#  'great experience',
#  'Extremely poor',
#  'inflight',
#  'trying receive compensation',
#  'managed lose baggage',
#  'Sheremetyevo airport poorly managed',
#  'luggage transferred',
#  'could put cage',
#  'Good',
#  'Never using Air Arabia',
#  'Staff seemed disinterested',
#  'Terrible company',
#  'poor',
#  'worst',
#  'personal inflight entertainment',
#  'Excellent',
#  'awful experience',
#  'Air Astana',
#  'The luggage policy sucks',
#  'Airline seems giving',
#  'back',
#  'recommend',
#  'refunding fully refundable tickets !',
#  'bad experience',
#  'dysfunctional bureaucracy',
#  'luggage delayed',
#  'buy meal',
#  'attendants nice',
#  'telling would fully reimbursed',
#  'disgust',
#  'Absolutely disgusting',
#  "n't give damn customers",
#  'nothing like old Aer Lingus loved flying',
#  'Excellent round',
#  'Overall satisfied',
#  "n't expect much",
#  'assisting wife',
#  'moved plane',
#  'awaiting refund',
#  'pay luggage',
#  'Aeroflot client support useless helpless',
#  'hard working crew',
#  'never use',
#  'way treated us awful',
#  'joke',
#  "probably wo n't",
#  'given bad treatment',
#  'Worst experience',
#  'high level',
#  'Terrible experience',
#  'Terrible client relationship',
#  'Air Astana',
#  'rude treated',
#  'putting lock/zip tie luggage',
#  'legs lost baggage',
#  'The best Europe',
#  'passed drinks',
#  'luggage arrived nine twelve days later',
#  'Meal good 90 min',
#  'reservation allowed',
#  'pay drinks transatlantic',
#  "Terrible ''",
#  'trash',
#  'avoid cost',
#  'received refund',
#  'terrible',
#  'treated unfriendly',
#  '8 days bags arrive',
#  'They lost luggage',
#  'food terrible',
#  'pleasantly surprised',
#  'worst traveling experience',
#  'one worst experience',
#  'disappoint',
#  'experience average',
#  'unbelievably attentive',
#  'Service attentive',
#  'significant improvements',
#  'memorable',
#  'never',
#  'Mean unkind employees',
#  'worst',
#  'Such terrible experience',
#  'change  paying 12 Euros',
#  'Aegean exceeded expectations',
#  'pay 50 euros',
#  'great highly recommended',
#  'Lost luggage 3 days ago',
#  "n't get much quality differs",
#  'lack support',
#  'would never use',
#  'Worst ever',
#  'Aer Lingus refuses provide voucher',
#  'managed avoid paying',
#  'Seats hard .. leg space good',
#  'lead 14 hour delay',
#  'Transfer worst experience',
#  'Great daytime',
#  'good experience',
#  'Worst worst',
#  'allows personal bag',
#  'allow 3kgs duty free',
#  'Excellent staff',
#  'claim missed transfer',
#  'upgrade',
#  'Not worst best',
#  'exceptional high standards',
#  'Fantastic cabin crew',
#  'would avoid costs',
#  'incredibly unprofessional frustrating',
#  'never',
#  '’ delayed every step journey',
#  "worst 've ever flown",
#  'Gold Air reached',
#  'inappropriate delay',
#  'still luggage',
#  'Professional on-board',
#  'hand luggage checked',
#  'Seats close together',
#  "'m using",
#  'left 9 hours airport',
#  'leaving customers hungry',
#  'Aer Lingus fallen long long way',
#  'one favourite',
#  'positive experience',
#  'Definitely avoid',
#  'happy',
#  "n't recommend",
#  'experience excellent',
#  'missed connection',
#  'Every delayed',
#  'Excellent inflight',
#  'missed connecting',
#  'never book',
#  'excuse avoid help us',
#  'stay Shajrah one day',
#  'worst life',
#  'good entertainment',
#  'write commend staff',
#  'staff nice friendly',
#  'crew attentive',
#  'The catering perfect',
#  'communication absolute worst',
#  'ever',
#  'said offer refund',
#  'pay extra different',
#  'extra hand luggage pay',
#  'allowed 8kg',
#  'Politely greeted door',
#  'denied full refund',
#  'short staffed unwilling assist',
#  'frills missing business class product',
#  'Worst ever  poor care',
#  'cheating customers',
#  'pricier budget',
#  'Not good first impression',
#  'nice crew comfortable planes',
#  'kept people bus',
#  'loaded 20 cans beer',
#  'CS helpful',
#  'staff closed gate',
#  'Pleasant experience',
#  'good experience',
#  'never treated worse',
#  'Avoid whenever',
#  'Absolutely appalling',
#  '7 hour without water',
#  'refuse bring hand luggage',
#  'tv screen work',
#  'expect good',
#  'wanted get refund',
#  'Very good experience',
#  'never',
#  'professional',
#  'Unbelievably terrible treatment',
#  'cabin crew told us take care ’ worry ! joke !',
#  'Aegean lost bag 7 days ago',
#  'Service good attentive always',
#  'checked-in luggage lost',
#  'exemplary',
#  'rude  negotiating aggressive',
#  'baggage lost',
#  'best ’ flown',
#  'nightmare',
#  'Only 3 bathrooms worked',
#  'stranded Europe another day',
#  'profit',
#  'line',
#  'trip worst',
#  'cramped limit',
#  'really pleasantly surprised',
#  'crew super-friendly',
#  'I´ll recommend',
#  'flights comfortable',
#  'excuse compensation',
#  '5-star onboard',
#  'dissatisfy',
#  'Absolutely horrible',
#  'last ever experience Air Arabia',
#  'miserable experience',
#  'food excellent',
#  'Service exceptional',
#  'Cabin crew effective',
#  'good great tasting food',
#  'amaze',
#  'avoid costs',
#  "n't type consideration",
#  'Delayed always',
#  'Worse experience',
#  'Pretty much airport online',
#  "Due personal reasons  ca n't",
#  "Excellent cabin crew ''",
#  'first choice',
#  'They lost 2 good clients',
#  'flexibility part business',
#  'cabin crew courteous efficient',
#  'left bad taste mouth',
#  'attendant going dictate',
#  'charged 100 dollars carry',
#  'managed lose 3 4 luggage',
#  'average budget carrier',
#  'Worst ever',
#  'Quality decent budget carrier',
#  'offer good quality',
#  'try use German Airlines AB shame',
#  'Good',
#  'follow rules',
#  'connecting missed',
#  'missed connecting',
#  'never use',
#  'poor',
#  'take care passengers',
#  'good value money',
#  'everything impeccable',
#  'recommended ? Of course',
#  'good representatives',
#  'pleasant event',
#  'refund sorry inconvenience',
#  'Arrived LAX missing luggage',
#  'miserable travel experience',
#  "Hopefully wo n't flying anymore",
#  'space considered acceptable business class',
#  'The complaints process long difficult use',
#  'middle available free',
#  'Excellent start finish',
#  'never get',
#  'My experience disgraceful',
#  'Absolutely disastrous',
#  'never recommend',
#  'guys joke',
#  'confuse',
#  'worst experience',
#  'never',
#  'outraged Air Berlin',
#  'spend 14 hours transit',
#  'Delayed 19 hours',
#  'Seat really good',
#  'luggage ended Cairo',
#  'We wait 14 hours',
#  'offers best value money',
#  'decent',
#  'offer good legroom',
#  'bad experience',
#  'economical ticket',
#  "All easy positive ''",
#  'let real bad',
#  'staff extremely helpful',
#  'Cabin crew welcoming',
#  'good experience',
#  'terrible - buyer beware !',
#  'Shame lack compassion extreme situations',
#  'The worst ever',
#  'essentially stolen £884 us',
#  'kept money canceled',
#  'clear steep decline',
#  'friendly professional staff',
#  'Good trip  recommended',
#  'overall experience pleasant',
#  'basic competence',
#  'unsure kids sit husband',
#  'change ticket pay difference',
#  'impressed Aer Lingus occasion',
#  'rather unpleasant experience',
#  'awful',
#  'worst experienced',
#  'never',
#  'leg space also reasonable',
#  'fly',
#  'transit Moscow airport chaotic',
#  'surfboards found',
#  'Best airport worker',
#  'huge queue late',
#  'surprised quality',
#  'trustworthy',
#  'Air Arabia',
#  'food good  excellent',
#  'Never flying avoid',
#  'Air Astana',
#  'extremely comfortable beds',
#  'nice crew good',
#  'The staff unhelpful rude',
#  'total joke',
#  'ignoring refund messages',
#  'offered us nothing lodging costs inconvenience',
#  'warm food offered',
#  'bags would 8 kilos allowed',
#  'Best value money',
#  'stressful inconvenient',
#  'things really frustrating',
#  'Absolute shambles start finish',
#  'Nobody support',
#  'poorly run budget',
#  'treated poorly baggage claim staff',
#  'rented budget ’ plane',
#  'Customer Service non-existent',
#  'incredible lack communication',
#  'good reasonable prices',
#  'Air Berlin',
#  'positive experience',
#  'pleasantly surprised',
#  'definitely travel Aeroflot',
#  'missing connecting',
#  'attendants nice',
#  'certainly',
#  'good quality services',
#  'meals almost non existent',
#  'frustrating disappointing experience',
#  'rude unprofessional',
#  'faced pay change',
#  'pay 100 pounds backpacks',
#  'The biggest letdown',
#  'worth frustration',
#  'free alcohol board',
#  'canceled short notice',
#  'overall great',
#  'need better terminal',
#  'personnel matter fact',
#  'company shame',
#  'tried upgrade',
#  'Excellent',
#  'charge overweight baggage',
#  'extremely disappointed',
#  'highly recommend Air Astana',
#  'exceeded expectations',
#  'made absolute breeze',
#  'smiling crew  clean cabin',
#  'Crew friendly',
#  'Disappointing fronts',
#  'horrible experience',
#  'covid test result expired',
#  'made pay way home',
#  'Nothing complain',
#  'They canceled',
#  'Aegean use like',
#  '2 kilos limit',
#  'pay 60 euros',
#  'One best transatlantic experiences',
#  "'ll stick future",
#  'looking another next time',
#  'Cabin crew friendly efficient',
#  'disgrace aviation industry',
#  "wo n't recommend anyone",
#  'pleasantly surprised',
#  'crews friendly professional',
#  'trouble basic services',
#  'Never',
#  'pleasant crew  nice food',
#  'enjoyed flying Aeroflot',
#  'value really good',
#  "n't get bags yet",
#  'comfortable uneventful',
#  'got worst travelling children',
#  'attendant kind',
#  'going strength strength',
#  'hub 4 Star',
#  'cabin crew friendly reasonable English',
#  "ca n't admit wrong",
#  '’ never',
#  'voided ticket',
#  'Stuck Airport 22 hours',
#  '45 mins connection window',
#  'snack',
#  'Efficient  friendly',
#  'pleased crew',
#  'frustrate',
#  'luggage missing',
#  'way check electronically',
#  'zero',
#  'friendly orientated crew',
#  'never airberlin',
#  "n't got board",
#  'would Air Berlin',
#  'excessive baggage fees',
#  'improving daily',
#  'amazing experience',
#  'definitely',
#  "luggage n't arrived",
#  'flights mostly uneventful',
#  'would certainly use',
#  'saw inflight entertainment',
#  'overall good experience',
#  'outrageous fee overweight baggage',
#  'Do choose',
#  'like street vendors',
#  'process downright horrific',
#  '’ refund replace ticket',
#  'Avoid',
#  'good in-flight',
#  'Online check great',
#  'Smooth  landed time',
#  '€40 board hand luggage',
#  'pay extra 50 euros',
#  'They offer help way',
#  'Very positive experience',
#  'important communication',
#  'supportive human attitude',
#  'neither respect care customers',
#  'incompetent disorganized',
#  'worst experience',
#  'Reserved ignored',
#  'useless Air Berlin',
#  'shameful lack',
#  '’ fault Aeroflot',
#  'know luggage',
#  '’ received baggage',
#  'Seats comfortable',
#  'still got nothing',
#  'plenty legroom',
#  'aircraft clean',
#  'friendly crew tasty food',
#  'seen major improvements',
#  'exceptional',
#  'You never know arrive belongings follow',
#  'baggage lost',
#  'If want lose money go ahead book',
#  "ca n't make changes online",
#  'crew kind friendly',
#  'use stair jetway',
#  'Thoroughly recommended',
#  'Absolutely terrible',
#  'superb',
#  'small cramped plane',
#  'wholly unreliable',
#  'Service abysmal',
#  'gave us two together',
#  'unfriendly rude',
#  'worst business class',
#  'staff unfriendly impatient',
#  'choose',
#  'Great friendly crew',
#  'cabin crew unfriendly',
#  '’ received baggage',
#  'refused provide compensation',
#  'left poor impression',
#  'true business class short haul Europe',
#  'good flights economy',
#  'attentive thorough staff',
#  'good',
#  'welcome perfect',
#  'deterioration check',
#  'rude unaccommodating',
#  'times late',
#  'really put nerves test',
#  'Never !',
#  'unacceptable !',
#  'experienced two time changes',
#  'Aegean Airlines changed',
#  'luggage damaged',
#  'Excellent  great crew . Very professional',
#  'took ownership mistake',
#  'never',
#  'made experience absolute nightmare',
#  'The comfortable',
#  'enjoy free baggage allowance selection',
#  'young cabin crew polite professional',
#  'really expect luggage',
#  'looks better',
#  'lost luggage times',
#  'staff polite friendly',
#  'luggage lost',
#  'Excellent',
#  'good value money',
#  'Thanks Air Astana',
#  'expensive return ticket',
#  'would Air Astana',
#  'lots legroom',
#  'never book',
#  'never travel using',
#  'would recommend',
#  'Worst air travel experience ever',
#  'They lost luggage',
#  'problem',
#  'felt like fooled',
#  'They ’ reply emails calls',
#  'charged £38 second carry-on item',
#  'terrible experience',
#  'They served terrible food',
#  'total nightmare working',
#  ...]

# %%
def preprocess_text(text):

    # Tokenize the text

    tokens = word_tokenize(text) #importante


    # Remove stop words

    filtered_tokens = [token for token in tokens if token not in stopwrd]

    # Lemmatize the tokens

    lemmatizer = WordNetLemmatizer() #como hay sólo 20k filas podemos lematizar. Si hay muchas...mejor steam

    lemmatized_tokens = [lemmatizer.lemmatize(token, pos="v") for token in filtered_tokens]

    # Join the tokens back into a string

    processed_text = ' '.join(lemmatized_tokens)

    return processed_text

# %%
df['TEXT'] = df['TITLE'].apply(preprocess_text)

# %%
sia=SentimentIntensityAnalyzer()

# %%
def get_sentiment(text):
    scores=sia.polarity_scores(text)
    sentiment=1 if scores["compound"]>0.25 else (-1 if scores["compound"]<-0.25 else 0)
    return sentiment

# %%
df.sample()
# Out:
#        Unnamed: 0 AIRLINENAME  CABINTYPE   DATEFLOWN              DATEPUB  \
# 59499       59710     Ryanair          1  2020-09-01  22nd September 2020
#
#        ENTERTAINMENTRATING  FOODRATING  GROUNDSERVICERATING ORIGINCOUNTRY  \
# 59499                    0           3                    1        Poland
#
#        OVERALLSCORE  RECOMMENDED  \
# 59499             2            0
#
#                                                   REVIEW              ROUTE  \
# 59499  Not a nice situation with the extra fee for th...  Catania to Cracow
#
#         ORIGIN DESTINY  SCALE_YN  SEATCOMFORTRATING  SERVICERATING     SLUG  \
# 59499  Catania  Cracow         0                  3              5  ryanair
#
#                                TITLE  TRAVELLER  PURPOSE  TRIPVERIFIED  \
# 59499  extra fee for the checking-in          2        1             1
#
#        VALUERATING  WIFIRATING                             UNIQUE_ID  \
# 59499            3           0  e241a67e-2623-497f-afb5-86e3a5c45a26
#
#        LONGDISTANCE  YEAR                        TOKENIZREVIEW  \
# 59499             0  2020  [extra, fee, for, the, checking-in]
#
#              filtered_tokens                   TEXT
# 59499  extra fee checking-in  extra fee checking-in

# %%
df["SENTIMENT"] =df["TEXT"].apply(get_sentiment)

# %%
df.drop(df[df['TEXT'] == df.AIRLINENAME].index, inplace=True) #drop those only based on the company airline name

# %%
df["SENTIMENT"]
# Out:
# 0        1
# 1       -1
# 2        0
# 3        0
# 4        1
#         ..
# 89969    0
# 89970   -1
# 89971    0
# 89972    0
# 89973    1
# Name: SENTIMENT, Length: 87383, dtype: int64

# %%
df.RECOMMENDED.value_counts()
# Out:
# RECOMMENDED
# 0    57586
# 1    29797
# Name: count, dtype: int64

# %%
df.SENTIMENT.value_counts()
# Out:
# SENTIMENT
#  0    35467
#  1    25986
# -1    25930
# Name: count, dtype: int64

# %%
df[df.SENTIMENT==1].OVERALLSCORE.value_counts()
# Out:
# OVERALLSCORE
# 10    6637
# 9     5293
# 8     4512
# 1     3460
# 7     2352
# 2      991
# 6      945
# 3      684
# 5      617
# 4      495
# Name: count, dtype: int64

# %%
df[df.SENTIMENT==1].TITLE.value_counts()
# Out:
# TITLE
# I was pleasantly surprised               85
# not recommend this airline               59
# service was excellent                    56
# a great experience                       51
# seats were comfortable                   50
#                                          ..
# super professional and attentive crew     1
# No smiles on this flight                  1
# fabulous hospitality                      1
# prices were good                          1
# plane was comfortable, enough legroom     1
# Name: count, Length: 20725, dtype: int64

# %%
df[df.SENTIMENT==0].OVERALLSCORE.value_counts()
# Out:
# OVERALLSCORE
# 1     17740
# 2      4285
# 3      2549
# 10     1910
# 8      1744
# 9      1630
# 7      1546
# 5      1430
# 4      1429
# 6      1204
# Name: count, dtype: int64

# %%
df[df.SENTIMENT==0].TITLE.value_counts()
# Out:
# TITLE
# never fly this airline again       128
# never fly with them again          115
# Emirates customer review            96
# Lufthansa customer review           86
# Qatar Airways customer review       85
#                                   ...
# double paid for return flight        1
# supervisor was unhelpful             1
# have a machine checking us in        1
# would not buy this ticket again      1
# no information given                 1
# Name: count, Length: 30204, dtype: int64

# %%
df[df.SENTIMENT==-1].OVERALLSCORE.value_counts()
# Out:
# OVERALLSCORE
# 1     16768
# 2      3825
# 3      2099
# 4      1065
# 5       812
# 6       425
# 7       357
# 8       238
# 9       176
# 10      165
# Name: count, dtype: int64

# %%
df[df.SENTIMENT==-1].TITLE.value_counts()
# Out:
# TITLE
# Terrible customer service           155
# Worst experience ever               137
# Worst airline ever                  133
# worst customer service              104
# Worst customer service              103
#                                    ...
# flight was severely delayed           1
# really disappointed with fastjet      1
# had the worst flight experience       1
# Most horrid experience                1
# don't expect great friendliness       1
# Name: count, Length: 19017, dtype: int64

# %%
texto="never" 
sia=SentimentIntensityAnalyzer()
sentimiento=sia.polarity_scores(texto)
sentimiento
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
#Keep only those data who make sense the result of the sentiment analysis and the overall score:
#negative: sent=-1 and overallscore 1-3
#neutral: sent=0 and overallscore 4-6
#positive: sent=1 and overallscore 7-10

df['SENTPLUS'] = ((df['SENTIMENT'] == 1) & (df['OVERALLSCORE'] > 6)) | \
                 ((df['SENTIMENT'] == 0) & ((df['OVERALLSCORE'] > 3) & (df['OVERALLSCORE'] < 6))) | \
                 ((df['SENTIMENT'] == -1) & (df['OVERALLSCORE'] < 4))

# Convert boolean results to integers (optional)
df['SENTPLUS'] = df['SENTPLUS'].astype(int)

# %%
df.SENTPLUS.value_counts()
# Out:
# SENTPLUS
# 1    44345
# 0    43038
# Name: count, dtype: int64

# %%
sentimentdf=df[df['SENTPLUS'] == 1]

# %%
sentimentdf[sentimentdf.SENTIMENT==1].TITLE.value_counts()
# Out:
# TITLE
# I was pleasantly surprised      81
# service was excellent           56
# a great experience              51
# good value for money            42
# a pleasant experience           40
#                                 ..
# had a fantastic flight           1
# Attendants welcomed us           1
# would still recommend            1
# a great flight with Emirates     1
# very quick and efficient         1
# Name: count, Length: 14515, dtype: int64

# %%
sentimentdf[sentimentdf.SENTIMENT==1].OVERALLSCORE.value_counts() #ok
# Out:
# OVERALLSCORE
# 10    6637
# 9     5293
# 8     4512
# 7     2352
# Name: count, dtype: int64

# %%
sentimentdf[sentimentdf.SENTIMENT==1].groupby(['AIRLINENAME', 'TITLE'])['OVERALLSCORE'].mean()
# Out:
# AIRLINENAME             TITLE
# AB Aviation             pretty decent airline                                    9.0
# ANA All Nippon Airways   service from FAs consistently excellent                 8.0
#                         ANA has very friendly staff                              8.0
#                         ANA is always a pleasure                                10.0
#                         ANA is simply the best                                  10.0
#                                                                                 ...
# flydubai                such a sweet and thoughtful gesture                     10.0
#                         the aircraft was clean                                  10.0
#                         very happy with the flight                               7.0
#                         very happy with the level of staff’s professionalism    10.0
#                         was pleasantly surprised                                10.0
# Name: OVERALLSCORE, Length: 18322, dtype: float64

# %%
sentimentdf[sentimentdf.SENTIMENT==0].groupby(['AIRLINENAME', 'TITLE'])['OVERALLSCORE'].mean()
# Out:
# AIRLINENAME             TITLE
# ANA All Nippon Airways  I was going to skip one flight                  5.0
#                         cannot reach them by phone                      4.0
#                         climb up stairs to the plane                    4.0
#                         could not upgrade my seat to Premium Economy    5.0
#                         flight was okay                                 5.0
#                                                                        ...
# flydubai                flydubai customer review                        4.0
#                         little leg room for a business class            4.0
#                         never fly with this airline again               5.0
#                         they charge for water                           5.0
#                         tv screen not working                           4.0
# Name: OVERALLSCORE, Length: 2762, dtype: float64

# %%
sentimentdf[sentimentdf.SENTIMENT==-1].groupby(['AIRLINENAME', 'TITLE'])['OVERALLSCORE'].mean()
# Out:
# AIRLINENAME             TITLE
# AB Aviation             Not a good airline                                1.0
# ANA All Nippon Airways  Horrendous seats on the 787                       2.0
#                         Upsetting to have to sit next to random people    2.0
#                         a lower class Economy fare                        1.0
#                         bad communication                                 3.0
#                                                                          ...
# flydubai                worst flight in my life                           1.0
#                         worst flight of my life                           1.0
#                         worst flight that I had                           3.0
#                         worst travel experience                           1.0
#                         worst traveling experience ever                   1.0
# Name: OVERALLSCORE, Length: 21256, dtype: float64

# %%
n_reviews_to_select = 3

# %%
random_sentences_pos = sentimentdf[sentimentdf.SENTIMENT==1].TITLE.sample(n=n_reviews_to_select, random_state=1).tolist()
random_sentences_pos
# Out:
# ['better than some main airlines',
#  'fantastic staff at Terminal 3',
#  'the price was great']

# %%
random_sentences_neg= sentimentdf[sentimentdf.SENTIMENT==-1].TITLE.sample(n=n_reviews_to_select, random_state=1).tolist()
random_sentences_neg
# Out:
# ['Very poor response from the team',
#  'on an old, dirty plane',
#  'poor inflight product and service']

# %%
#Filter dataframe based on positive and negative sentiment analysis and get a positive and negative review by airline
neg_sentiment_df = sentimentdf[sentimentdf['SENTIMENT'] == -1]

pos_sentiment_df = sentimentdf[sentimentdf['SENTIMENT'] == 1]


for airline in sentimentdf['AIRLINENAME'].unique():
    print(airline)
    
    
    airline_neg_df = neg_sentiment_df[neg_sentiment_df['AIRLINENAME'] == airline]
    if len(airline_neg_df) > 0:
        random_sentences_neg = airline_neg_df['TITLE'].sample(n=1, random_state=1).tolist()
    else:
        random_sentences_neg = "no negative reviews"
    print(random_sentences_neg)
    
    
    airline_pos_df = pos_sentiment_df[pos_sentiment_df['AIRLINENAME'] == airline]
    if len(airline_pos_df) > 0:
        random_sentences_pos = airline_pos_df['TITLE'].sample(n=1, random_state=1).tolist()
    else:
        random_sentences_pos = "no positive reviews"
    print(random_sentences_pos)
# Out:
# AB Aviation
# ['Not a good airline']
# ['pretty decent airline']
# Aero VIP
# no negative reviews
# ['the support was fantastic']
# Adria Airways
# ['worse than the budget airlines']
# ['Two nice short flights']
# Aeromar
# ['such bad customer service']
# ['service was excellent']
# Africa World Airlines
# no negative reviews
# ['An excellent service']
# Aigle Azur
# ['Worst airline I experienced']
# ['they could smile a bit more']
# Aerolineas Argentinas
# ['service was generally unfriendly']
# ['Nice experience']
# Air Algerie
# ['checked in luggage was lost']
# ['Very good flight']
# Air Antilles
# ['This airline is disgusting']
# ['pleasant and relaxed flight']
# Aeroflot Russian Airlines
# ['They have a bad pillow']
# ['very good impression']
# Air Austral
# ['disappointed with my flight']
# ['crew were outstanding']
# Air Arabia
# ['never will recommend']
# ['very good experience']
# Air Burkina
# no negative reviews
# ['a positive experience']
# Air Botswana
# ['the worst travel experience']
# no positive reviews
# Air Busan
# ['was a disaster']
# ['Great value budget airline']
# Air Astana
# ['not at all apologetic for the delay']
# ['flight attendants are very nice']
# Aeromexico
# ['both legs of the flight I lost my baggage']
# ['flight attendants were satisfactory']
# Aer Lingus
# ['was 23 hours delayed']
# ['a great airline']
# Aegean Airlines
# ['a problem in the flight']
# ['it felt efficient and hospitable"\n']
# Air Cairo
# ['cheap low profile airline']
# ['both flights were comfortable']
# Air Caraibes
# ['refused to refund my money']
# ['improvements can be made']
# Air Costa
# no negative reviews
# ['a great experience']
# Air Corsica
# ['Extremely poor customer service']
# ['Excellent all round']
# Air Berlin
# ['low language knowledge of the crew']
# ['nice crew and comfortable planes']
# Air China
# ['Worst travel experience']
# ['good value for money']
# Air Canada rouge
# ['seats are quite uncomfortable']
# ['was a very pleasant experience']
# Air Canada
# ['one of the worst airlines']
# ['great service onboard']
# Air Greenland
# ['bad customer service']
# ['a satisfactory experience']
# Air Cote d'Ivoire
# ['A dreadful experience all the way']
# no positive reviews
# Air Iceland Connect
# no negative reviews
# ['Absolutely wonderful flight']
# Air Djibouti
# no negative reviews
# ['Plane was in a good condition']
# Air Dolomiti
# ['Terrible mismanagement and incompetence']
# ['a great experience']
# Air Italy
# ['I literally was trapped']
# ['smooth and very pleasant']
# Air KBZ
# no negative reviews
# ['professional and pleasant']
# Air Juan
# ['the worst experiences of airlines']
# ['flight was comfortable']
# Air India Express
# ["entire cabin wasn't in good condition"]
# ['crew surprisingly good']
# Air Koryo
# ["they don't pay attention to safety"]
# ['The food was acceptable']
# Air Macau
# ['worse than a budget airline']
# ['had a great experience']
# Air Madagascar
# ['airline is a disaster']
# no positive reviews
# Air Europa
# ['riot created at the gate']
# ['definitely use this airline again']
# Air Moldova
# ['Very badly organized company']
# ['thanks to the staff']
# Air Malta
# ['The service unfriendly']
# ['Overall a great flight']
# Air Mauritius
# ['The worst flight']
# ['cabin service was outstanding']
# Air Namibia
# ['various bad experiences']
# ['crew were friendly and helpful']
# Air North Yukon's Airline
# no negative reviews
# ['wonderful friendly airline']
# Air Niugini
# ['an epic disappointment']
# ['decent amount of entertainment']
# Air Nostrum
# ['very unpleasant experience']
# ['very good short flight']
# Air Pegasus
# ['worst customer service']
# ['amazing customer service']
# Air Panama
# ['airline is terrible']
# ["really friendly and smiling FA's"]
# Air Rarotonga
# no negative reviews
# ['a pleasurable experience']
# Air Seychelles
# ['Air Seychelles is a catastrophe']
# ['friendly efficient crew']
# Air Tahiti Nui
# ['the worst airline I have flown']
# ['staff on the plane were pleasant']
# Air Tanzania
# ['regret to have travelled with Air Tanzania']
# ['staff were professional and helpful']
# Air Vanuatu
# ['Two very bad experiences']
# ['I recommend Air Vanuatu']
# Air Serbia
# ['planes are in horrible condition']
# ['seats were comfortable" ']
# Air Zimbabwe
# ['a very bad experience']
# ['crew were very friendly']
# Air India
# ['Overall a poor experience']
# ['better than expectation']
# Air France
# ['this was the worst experience']
# ['Wonderful flight']
# Air New Zealand
# ['poor customer service']
# ['delightful staff, great snacks']
# Air Transat
# ['worst travel experience']
# ['cabin crew very agreeable']
# AirAsia Zest
# no negative reviews
# ['happy with the service']
# Aircalin
# no negative reviews
# ['superb full course French meal']
# airblue
# ['Very poor service']
# ['cabin crew was nice']
# AirAsia Philippines
# ['The seats are miserable']
# ["haven't had a bad experience from them"]
# AirAsia India
# ['Poor seating arrangement']
# ['Kudos to the entire team!']
# AirSWIFT
# no negative reviews
# ['Good service in flight']
# Airlink
# ['staff was so unnecessarily rude']
# ['definitely recommend Airlink']
# Airnorth
# ['Had the worst experience with Air North']
# ['surprised by the high quality']
# Akasa Air
# ['Boarding is entire chaos']
# ['it just was efficient and smooth']
# airBaltic
# ['refused to give me a refund']
# ['excellent service']
# AirAsia X
# ['Delay after constant delay']
# ['efficient and no-nonsense']
# Alliance Air
# ['Very poor approach by the staff']
# ['seat configuration was comfortable']
# Alliance Airlines
# ['I would avoid this airline at all costs']
# no positive reviews
# Amaszonas
# ['Amaszonas is a disgrace']
# ['experience with Amaszonas was good']
# AnadoluJet
# ['always at least 1 hour delay']
# ['Nice staff, Good coffee"\n']
# American Eagle
# ['American Eagle should be ashamed']
# ['an amazing flight attendant']
# AirAsia
# ['delayed due to technical problems']
# ['excellent airline food']
# Andes Líneas Aéreas
# ['avoid at all costs']
# no positive reviews
# Arik Air
# ['shabby and unprofessional']
# ['have improved their services']
# Alitalia
# ['Horrible customer service']
# ['was pleasantly surprised']
# Arkia Israeli Airlines
# ['Absolutely awful experience']
# ['cabin crew were friendly']
# Armenia Air Company
# ['worst and non-reliable airline']
# no positive reviews
# ASKY Airlines
# ['Very Terrible Experience']
# ['staff competent']
# ANA All Nippon Airways
# ['cabin staff  ignored me']
# ['extremely clean, but looked old']
# Alaska Airlines
# ['I’m sick and tired of flying this airline']
# ['great, friendly, caring']
# Atlantic Airways
# no negative reviews
# ['very pleasant']
# Asiana Airlines
# ['most uncomfortable']
# ['extremely comfortable and smooth ride']
# Allegiant Air
# ['worst airline I have ever flown']
# ['Good value for the money']
# American Airlines
# ['Unacceptable treatment and unreasonable accommodation from AA']
# ['they had my best interest in mind']
# Auric Air
# no negative reviews
# ['Check-in was efficient']
# Aurigny Air
# ['treated me like a suspected terrorist']
# ['recommend this airline']
# Avianca Brazil
# ['staff were incompetent']
# ['I was very impressed']
# Avianca Ecuador
# ['absolutely terrible service']
# no positive reviews
# Atlasglobal
# ['nothing to try to help me resolve this']
# ['will definitely use them again']
# Avelo Airlines
# ['it is completely meaningless']
# ['I’ll definitely fly again']
# Avior Airlines
# ['Terrible experience']
# no positive reviews
# Azur Air Germany
# ['seats extremely uncomfortable']
# no positive reviews
# Badr Airlines
# no negative reviews
# ['great flight and experience']
# Azerbaijan Airlines
# ['airline is one of the worst']
# ['service is really good']
# Azul Airlines
# ['customer service was horrible']
# ['good working free WIFI']
# BA CityFlyer
# no negative reviews
# ['would recommend CityFlyer']
# Bahamasair
# ['100% unacceptable']
# ['The crew were very friendly']
# Bamboo Airways
# ['bad attitude from the staff']
# ['Definite value for money']
# Bassaka Air
# no negative reviews
# ['brilliant in all aspects']
# Beijing Capital Airlines
# no negative reviews
# ['were in excellent service']
# Belavia
# ['service onboard was awful']
# ['very nice flight']
# BH Air
# ["don't care a lot for customers"]
# no positive reviews
# Bhutan Airlines
# ['Bhutan experience turned bad']
# ['good things to say']
# Batik Air
# ['Delay after delay']
# ['flight was enjoyable']
# Avianca
# ['uninterested and unfriendly']
# ['recommend Avianca Economy class']
# Binter Canarias
# ['unfair policy towards its customers']
# ['Excellent airline']
# Blu-express
# ['Horrendous experience']
# no positive reviews
# Blue Islands
# ['Avoid at all costs']
# no positive reviews
# Bangkok Airways
# ['a massive disappointment']
# ['extremely helpful and friendly']
# Biman Bangladesh Airlines
# ['Boeing 777-200 was so bad']
# ['happy to fly with Biman']
# Austrian Airlines
# ['Cost cutting to the max']
# ['I recommend this airline']
# Blue Air
# ["they didn't seem interested to help at all"]
# ['amazing price 39,98 EUR return']
# Blue Panorama Airlines
# ['middle name change scam']
# ['cabin crew friendly .. food always the same']
# Blue1
# ['the worst service I have experienced']
# no positive reviews
# Bluebird Airways
# ['Seats extremely narrow and uncomfortable']
# no positive reviews
# bmi Regional
# ['poor customer services']
# ['enjoyed the small plane experience']
# Boliviana de Aviacion
# ['flight was annoying']
# ['can recommend it']
# Boutique Air
# ['This airline failed me']
# ['nice having a reliable company']
# Breeze Airways
# ['denied boarding without giving a valid reason,']
# ['Seats comfortable. Staff friendly']
# Brussels Airlines
# ['This is a terrible airline']
# ['I recommend Brussels Airlines']
# Camair-Co
# ['flight was delayed by 10 hours']
# no positive reviews
# Cambodia Airways
# no negative reviews
# ['definitely use the airline again']
# Buddha Air
# ['Unprofessional customer service']
# ['Buddha Air did a good job']
# Buta Airways
# ['a very poor experience']
# ['definitely the best Low Cost Carrier']
# Cambodia Angkor Air
# ['An unprofessional airline']
# ['recommend this airline']
# Bulgaria Air
# ['incompetent staff and slow email']
# ['staff was very friendly']
# Canaryfly
# ['Not a great experience']
# ['The flight was enjoyable']
# Canadian North
# no negative reviews
# ['is a nice airline']
# Cape Air
# ['never recommend Cape Air']
# no positive reviews
# Caribbean Airlines
# ['I filed a dispute']
# ['highly recommend them']
# Cathay Dragon
# ['neither friendly or supportive']
# ['service by crew members was good']
# British Airways
# ['Nothing special or memorable']
# ['cabin crew where fantastic']
# Central Mountain Air
# ['Terrible service/planning']
# ['amazing customer service']
# Cayman Airways
# ['worst flying experience']
# ['was a great experience']
# China United Airlines
# ['worst airline I ever been on ']
# no positive reviews
# CityJet
# ['very unpleasant experience']
# ['crew very good']
# Citilink
# ['should be postponed or worse cancelled']
# ['flight attendants were very courteous and polite']
# Cebu Pacific
# ['highly unprofessional']
# [' I remain very satisfied']
# Coastal Aviation
# no negative reviews
# ['experienced excellent customer service']
# China Eastern Airlines
# ['was something close to hell']
# ['pleasantly surprised']
# Comair
# ['disappointed with the experience']
# ['a really nice experience']
# Cobalt
# ['woeful customer service']
# ['we were very surprised']
# Corendon Airlines
# ['awful company"\n']
# ['crew was very nice']
# Corsair
# ["don't care about their customers"]
# ['kind and helpful staff']
# Croatia Airlines
# ['the most horrible flight experience']
# ['very pleasant flight']
# Copa Airlines
# ['worst airline I have ever travelled']
# ['The aircraft and comfort were impeccable']
# Condor Airlines
# ['unacceptable handling of the matter']
# ['grateful for help Condor provided']
# Cubana Airlines
# ['our luggage was lost']
# ['I would recommend Cubana']
# CSA Czech Airlines
# ['poor quality 2-star low-cost']
# ['the crew very professional and friendly']
# Danish Air Transport
# ['was the worst experience']
# no positive reviews
# Cyprus Airways
# ['Just disgusting']
# ['satisfied with this airline']
# Darwin Airline
# no negative reviews
# ['better than I was expecting']
# Druk Air
# no negative reviews
# ['fantastic little airline']
# Dragonair
# ['flight is always delayed']
# ['dependable, satisfactory service']
# Eastern Airlines
# ['It was a highly stressful ordeal']
# no positive reviews
# Eastar Jet
# ['Very horrible service']
# ['satisfied of services and staff']
# Eastern Airways
# ['very cramped and noisy']
# ['most impressed by the service on this flight']
# Easyfly
# ['worst airline I ever knew.']
# ['pleased we chose EasyFly']
# Edelweiss Air
# ['food is absolutely awful and totally sub-standard for business class']
# ['recommend this airline']
# El Al Israel Airlines
# ['One of the worst airlines']
# ['All in all a good flight']
# Egyptair
# ['very unsatisfied customer']
# ['much improved airline']
# Ellinair
# ['items stolen during baggage handling']
# ['crew very helpful and friendly']
# China Southern Airlines
# ['Boeing 787 uncomfortable seats']
# ['It was a pleasant journey']
# Estonian Air
# no negative reviews
# ['crew friendly and smiling']
# easyJet
# ['they have refused reimbursement']
# ['pleasantly surprised by the experience']
# euroAtlantic Airways
# ['most awful flight']
# ['pleasant long haul flight']
# Ethiopian Airlines
# ['ignored requests to compensate expenses']
# ['Overall I would recommend']
# Evelop Airlines
# ['Avoid at all costs']
# no positive reviews
# Emirates
# ['allocated the wrong seats']
# ['experienced excellent service']
# Eurowings
# ['Worst flying experience']
# ['definitely fly Eurowings again']
# Far Eastern Air Transport
# no negative reviews
# no positive reviews
# Etihad Airways
# ['avoiding their responsibility']
# ['service itself was great']
# EVA Air
# ["I can't recommend them"]
# ['an excellent experience']
# Fiji Airways
# ['disappointed with service at Nausori']
# ['crew was friendly, welcoming']
# Fly540.com
# ['shame on you Fly 540']
# ['excellent little airline']
# fastjet
# ['a serious disappointment']
# ['very friendly staff']
# Firefly
# ['poor management']
# ['onboard service was courteous']
# Flair Airlines
# ['Flair denied reimbursement']
# ['Thank you, Flair!']
# Finnair
# ['worst business class service']
# ['I recommend Finnair']
# flybe
# no negative reviews
# ['I was very happy with flybe service']
# FlyArystan
# no negative reviews
# ['lack of credit card payment support']
# flyadeal
# ['Hidden charges always leave the clients with negative experience']
# no positive reviews
# Flynas
# ['The food on this airline is the absolute worst']
# ['organised and efficient']
# FLYONE
# ['just stress and uncertainty']
# no positive reviews
# Freebird Airlines
# ['disgusted by their treatment']
# ['would be happy to fly with again']
# flydubai
# ['The worst airline in my life']
# ["best cabin crew I've seen"]
# FlySafair
# ['the lack of initiative']
# ['great service onboard']
# Germania Airline
# ['airline drives me insane']
# ['definitely choose Germania again']
# Georgian Airways
# ["don't care about passengers"]
# ['cabin service was kind']
# French Bee
# ['to fix the error was $200']
# ['good value for money']
# Germanwings
# ['I was refused some water']
# ['impressed with Germanwings']
# Grand Cru Airlines
# no negative reviews
# ['staff were so friendly']
# Golden Myanmar Airlines
# no negative reviews
# ['pleasant and positive']
# Gol Transportes Aéreos
# ['complaints line of GOL was totally inadequate']
# ['staff were extremely friendly']
# Go First
# ['The worst airline ever']
# ['pay extra amount for the free seats']
# GoAir
# ['worst service ever']
# ['The crew was very caring']
# Greater Bay Airlines
# ['avoid using this airline']
# no positive reviews
# Helvetic Airways
# ['it has become worse and worse']
# ['Very pleased with service']
# Garuda Indonesia
# ['worst experience']
# ['a very impressive service']
# Gulf Air
# ['Awful customer service']
# ['good food and service']
# Hainan Airlines
# ['Very poor customer service']
# ['a happy surprise to me']
# Hawaiian Airlines
# ['very disappointed with the upgrade']
# ['thank you Hawaiian for a job well done']
# Himalaya Airlines
# ['shocked at the unprofessional attitude']
# no positive reviews
# China Airlines
# ['always a painful experience']
# ['everything was great']
# HiSky
# ['Avoid at all costs']
# no positive reviews
# Hi Fly
# ['Terrible experience, never again']
# ['this was a great flight']
# HK Express
# ['Shocking experience']
# ['definitely fly with HK Express again']
# Frontier Airlines
# ['worst flying experience']
# ['giving me courage to fly again']
# Hunnu Air
# no negative reviews
# ['pleasantly appointed ATR 72']
# Horizon Air
# ['Very disappointed']
# ['crew was extremely nice']
# HOP!
# ['they fail to see the problem']
# ['services are good']
# Hong Kong Airlines
# ['staff were rude']
# ['overall a nice experience']
# Cathay Pacific Airways
# ['disappointed with the experience']
# ['the food was fantastic']
# Iberia
# ['chaotic boarding situation ']
# ['the experience is great']
# Intercaribbean Airways
# ['The absolute worst airline']
# no positive reviews
# Insel Air
# ['worst airline I have flown']
# ['attendants kind and attentive']
# Iberia Express
# ['worst airline I have ever flown']
# ['a nice experience']
# Interjet
# ['disaster of an experience']
# ['sympathetic and understanding']
# Icelandair
# ['seats are miserable']
# ['definitely travel with them again']
# IndiGo
# ['rude and unsupportive staff']
# ['a loyal traveller with IndiGo']
# Iraqi Airways
# no negative reviews
# ['satisfied with my flight']
# Israir Airlines
# no negative reviews
# ['cabin crew was good']
# Island Air
# ['the worst customer service ']
# ['cabin crew were great']
# Iran Air
# ['the worst experience']
# ['staff professional and very friendly']
# JC International Airlines
# ['avoid this company at all costs']
# no positive reviews
# Jazz
# no negative reviews
# ['Service on board was good']
# Jeju Air
# ['worst travel experience to date']
# ['plane clean, friendly attendants']
# Jazeera Airways
# ['worst customer service ever']
# no positive reviews
# ITA Airways
# ['impolite and incompetent" ']
# ['Pleasant crews, orderly boarding']
# Jetairfly
# ['a 10 hour delay?']
# ['recommend in this cabin']
# JetSmart
# ['really bad experience']
# ['value for money was great']
# Jetstar Japan
# ['it was a big mistake']
# ['Every flight was perfect']
# Jetstar Asia
# ['customer service terrible']
# ['value for money']
# Japan Airlines
# ['seat and vegetarian meal requests were ignored']
# ['the service was just excellent']
# Jet Airways
# ['Very disappointed with Jet Airways']
# ['very satisfying experience']
# JetsuiteX
# no negative reviews
# ['free drinks great snacks']
# Joon
# ['the worst experience']
# ['recommend all the way']
# Jin Air
# ['Very poor service']
# ['friendly flight attendants']
# Jetstar Pacific
# ['refund which they denied']
# ['ended up very pleasantly surprised']
# Jordan Aviation
# ['They are an unprofessional nightmare']
# ['Seems like a well run airline']
# Jetstar Airways
# ['Bad timing, bad service']
# ['like flying Jetstar whenever I can']
# Kan Air
# no negative reviews
# ['small but very efficient airline']
# Jetblue Airways
# ['they are really crazy rude']
# ['attendants were more than friendly']
# Juneyao Airlines
# ['I was so disappointed']
# ['very enjoyable experience']
# Kenya Airways
# ['delaying our flight by 4hr 15mins']
# ['excellent value for money']
# Delta Air Lines
# ['the absolute worst experience']
# ['food was delicious']
# Kish Airlines
# no negative reviews
# no positive reviews
# LAM Mozambique
# ["they don't care, don't fly LAM"]
# ['excellent value for money']
# Kulula
# ['So disappointed in Kulula!']
# ['Nice airline, on time']
# La Compagnie
# ['a terrible experience']
# ['Great from beginning to end']
# Kuwait Airways
# ['shocking manners of staff on board']
# ['Enjoyed my trip']
# Lao Airlines
# no negative reviews
# ['Friendly airline']
# LAN Colombia
# no negative reviews
# ['a pleasant experience']
# LAN Peru
# no negative reviews
# ['helping make our trip great']
# Lao Skyway
# ["I won't recommend at all"]
# ['staff friendly and courteous']
# LAN Airlines
# ['plane is a torture chamber']
# ['loved the cabin interior']
# Level
# ['without free food or water']
# ['I will recommend the airline']
# Korean Air
# ['ground staff service unacceptable']
# ['Staff professional and friendly']
# LC Perú
# ['frustrating and stressful time']
# ['I would recommend this airline']
# Libyan Airlines
# no negative reviews
# ['WIFI was pretty fast']
# Laudamotion
# ['lost us as customers']
# ['flight was great']
# LIAT
# ['disgusted with the service']
# ['All staff interactions were great']
# Lion Air
# ['very disappointing']
# ['it is good journey']
# Lubeck Air
# no negative reviews
# ['Great little airline']
# Loganair
# ['11 hours delay and cancellation']
# ['possibly the best ever']
# LATAM Airlines
# ['a drop in the quality of services']
# ['not as good as it should be']
# Lynx Air
# ['fail in actually flying you anywhere']
# ['I would highly recommend Lynx Air']
# Madagasikara Airways
# no negative reviews
# ['excellent service onboard']
# KLM Royal Dutch Airlines
# ['The worst flight experience']
# ['delighted by the kindness']
# Luxair
# ['Staff was very rude']
# ['Nice and smooth flight']
# LOT Polish Airlines
# ['lacks any understanding']
# ['would definitely fly LOT again']
# Malawian Airlines
# ['now probably the worst in the world']
# ['flight was surprisingly good']
# Mahan Air
# no negative reviews
# ['overall a good flight']
# Maldivian
# ['delayed flight for almost 2 hours']
# ['flight attendants were helpful']
# Mandarin Airlines
# no negative reviews
# ['seat is comfortable and wide']
# Mango Airlines
# ['we were 1.6 kg overweight']
# ['good choice for domestic travel']
# Manta Air
# no negative reviews
# ['Perfect short and comfortable flight']
# Mann Yadanarpon Airlines
# no negative reviews
# ['very friendly cabin']
# Malindo Air
# ['stolen out of my checked luggage']
# ['better than service from Air Asia']
# Malaysia Airlines
# ['Very disappointing']
# ['A good value flight']
# Lufthansa
# ['worst flight experience ever']
# ['efficient, friendly and helpful']
# MAYAir
# ['worst customer service']
# no positive reviews
# MEGA Maldives Airlines
# no negative reviews
# no positive reviews
# MIAT Mongolian Airlines
# ['quality of flight is very bad']
# ['ok but not worth raving about']
# Meridiana
# ['every second is horrible']
# ['service onboard was good']
# Middle East Airlines
# ['unpleasant and costly experience']
# ['an excellent flight']
# Myanmar Airways
# no negative reviews
# ['kind and focused service']
# Mihin Lanka
# ['food is another big hate']
# ['Crew was quite active']
# Motor Sich Airlines
# no negative reviews
# ['definitely fly Motor Sich again']
# Mokulele Airlines
# ['Horrible company']
# no positive reviews
# Montenegro Airlines
# ['worst flight I ever did']
# ['nice cabin crew only speak in Serbian']
# Monarch Airlines
# ['food service was very disappointing']
# ['very happy with this service']
# Myanmar National Airlines
# no negative reviews
# ['Quick, efficient, professional']
# Nauru Airlines
# no negative reviews
# ['staff friendly and hospitable']
# NAM Air
# ['Worst customer service']
# ['enjoyed my flight']
# Nature Air
# ['Avoid this airline']
# ['Thanks for the personal touch']
# Nepal Airlines
# ['my worst experience']
# ['Overall the flight was good']
# NokScoot
# no negative reviews
# ['a good flight']
# Nile Air
# no negative reviews
# ['quite an acceptable airline']
# Nordavia
# no negative reviews
# [' airline is very good']
# NIKI
# ['should be ashamed of your policy']
# ['impressed with everything']
# Nok Air
# ['cancelled, re-scheduled, delayed']
# ['service has improved']
# Norse Atlantic Airways
# ['my second 2.5 hour delay this week']
# ['one of the best experiences']
# Nordwind Airlines
# no negative reviews
# ['would fly again and recommend']
# NordStar
# no negative reviews
# ['a satisfactory experience']
# Novoair
# ['Worse airline ever']
# ['Not a bad airline!']
# Nouvelair
# ['A very bad experience']
# ['Very friendly staff and excellent service']
# Olympic Air
# ['the worst airline']
# ['crew service was excellent']
# Omni Air International
# ['worst airline I have ever flown']
# ['feel welcome and comfortable']
# Orient Thai Airlines
# no negative reviews
# ['I am very satisfied']
# Openskies
# ['wreaked havoc on our vacation']
# no positive reviews
# Onur Air
# ['worst experience I have had flying']
# ['a good deal for the price I paid']
# PAL Express
# no negative reviews
# ['the crew were amazing']
# Pacific Airlines
# ['Worst airline in Vietnam']
# no positive reviews
# Pakistan Intl Airlines
# ['8 hours of torture']
# ['comfortable timely flight']
# Peach Aviation
# ['Completely uncomfortable']
# ['the best low-cost airline']
# Oman Air
# ['delayed by more than six hours']
# ['the service was excellent']
# Passion Air
# ['They are extremely unprofessional']
# no positive reviews
# Norwegian
# ['an unnecessary and stressful start']
# ['plane Wi-Fi worked excellently']
# PAWA Dominicana
# no negative reviews
# ['service was pretty good']
# PenAir
# ['terrible customer service']
# ['service friendly and professional']
# Petroleum Air Services
# ['The service is disgusting']
# ["Couldn't fault it"]
# Peruvian Airlines
# ['caused me so many problems']
# ['aircraft was basic but clean']
# PLAY
# ['Very frustrating experience']
# ['Excellent service']
# Pegasus Airlines
# ['I wouldn\'t recommend" ']
# ['my experience  was great']
# Primera Air
# ['can only summarise as awful']
# ['was great value for money']
# Privilege Style
# ['avoid flying with them']
# ['I had an amazing experience']
# Pobeda Airlines
# ['error on the website']
# ['very good low-cost airline']
# Precision Air
# ['This airline is a disaster']
# ['great value for your money']
# Porter Airlines
# ['delayed and then canceled']
# ['certainly fly Porter again']
# Qazaq Air
# no negative reviews
# ['impressed with the service']
# Ravn Alaska
# ['Incompetence, rudeness, unreliability and overall poor service']
# ['overall experience was fantastic']
# QantasLink
# ['annoyed with the service']
# ['Very relaxed flight']
# Philippine Airlines
# ['flight was delayed by one hour']
# ['flight and crew are perfect']
# Red Wings Airlines
# ['worst experience of my life']
# no positive reviews
# Regent Airways
# ['Terrible experience']
# ['seats were good pitch']
# Regional Express
# ['worst customer service']
# ['a fresh choice for Australians']
# Rex Airlines
# ['The worst experience ever']
# ['it just keeps getting better and better']
# Rhein-Neckar Air
# no negative reviews
# ['Great experience']
# Rossiya Airlines
# no negative reviews
# ['friendly staff won me over']
# Rwandair
# ['waste of time and money']
# ['Excellent service']
# Royal Air Maroc
# ['ignore their customers']
# ['entertainment not working']
# Royal Jordanian Airlines
# ['dread our return flight']
# ['most pleasant crew']
# Royal Brunei Airlines
# ['lack of customer service']
# ['great value for money']
# Qantas Airways
# ['Very poor customer service']
# ['The food is delicious']
# Safarilink
# no negative reviews
# ['Crews were friendly']
# Safi Airways
# ['Safi Airways are terrible']
# no positive reviews
# SA Express
# ['I am extremely disappointed']
# ['excellent customer service']
# S7 Siberia Airlines
# ['Avoid this company']
# ['Highly recommended']
# Sansa Airlines
# ['Avoid this airline']
# ['would highly recommend']
# Salam Air
# ['Worst fight ever seen']
# no positive reviews
# Santa Barbara Airlines
# ['avoid this airline']
# no positive reviews
# SATENA
# ["don't recommend using this airline"]
# ['excellent choice for domestic travel']
# SATA International
# ['disdain I have for SATA']
# ['crew were friendly and responsive']
# SATA Air Azores
# ['Worthless customer service']
# ['the best customer service']
# Saudi Arabian Airlines
# ['Jeddah Airport one of the worst places ']
# ['pleasant flight attendants']
# SAS Scandinavian
# ['Avoid this airline at all costs']
# ['pleasant and comfortable']
# Qatar Airways
# ['6 hour delay to outbound flight']
# ['onboard service is fantastic']
# Ryanair
# ['The worst airline ever']
# ['good service and reasonable price']
# SCAT Airlines
# no negative reviews
# ['inflight a nice sandwich']
# SereneAir
# ['already delayed 2 hours!']
# ['A very courteous welcome']
# Shaheen Air
# no negative reviews
# ['good quality food served']
# Seaborne Airlines
# ['disgusted by the treatment']
# no positive reviews
# Scoot
# ['worst airline we have flown']
# ['Very friendly crew']
# Shandong Airlines
# ['ticket was booked wrong']
# ['Overall a good journey']
# Shanghai Airlines
# ['have the worst customer service']
# ['punctuality, good service']
# Sichuan Airlines
# ['completely ignore non-Chinese']
# ['lunch was delicious and generous']
# Shenzhen Airlines
# ['return flight was terrible']
# ['smooth and pleasant']
# Silver Airways
# ['uncomfortable seating and general unpleasantness"\n']
# ['our experience was very positive']
# SilkAir
# ['It delays all the time']
# ['demonstrating good service ']
# Sky Express Airlines
# ['So much stress, so little customer service']
# ['service was great and friendly']
# Skytrans Airlines
# ['absolutely chaotic from the start']
# ['recommend this airline']
# SkyUp Airlines
# ['the worst airline I have ever coame across!']
# ['an interesting airline']
# Skybus
# ['company were unmoved by the inconvenience']
# no positive reviews
# Skymark Airlines
# no negative reviews
# ["best budget airline I've flown with"]
# Sky Airline
# ['unpleasant flying experiences']
# ['a great experience']
# SkyWest Airlines
# no negative reviews
# ['big thank you to staff']
# Smartavia
# ['Avoid flying, unless really necessary']
# no positive reviews
# SkyWork Airlines
# ['Another disappointment']
# ['Service was friendly']
# SmartLynx Airlines
# ["worst flight I've ever been on"]
# ['Friendly and helpful crew']
# SmartWings
# ['both flights were delayed']
# ['love this air company']
# Small Planet Airlines
# ['flight delayed by 15 hours']
# ['good selection of food - nothing to complain about']
# Singapore Airlines
# ['has disappointed us']
# ['a fantastic flight']
# Somon Air
# ['airline is a complete disaster']
# no positive reviews
# Solomon Airlines
# no negative reviews
# ['very good service']
# South African Airways
# ['very disappointed']
# ['really good food']
# Spring Airlines
# ['avoid Spring Airlines']
# ['want to save tons of money']
# StarFlyer
# no negative reviews
# ['extremely friendly and quick']
# Star Peru
# ['Brutal delays. Missed connection']
# ['pleasantly surprised']
# Sriwijaya Air
# ['hows very poor management']
# ['seat was comfortable']
# SpiceJet
# ['Worst experience']
# ['Check in was great']
# SriLankan Airlines
# ['Appalling customer service']
# ['comfortable economy flights']
# Sun Country Airlines
# ['This ruined our honeymoon']
# ['attendants were professional yet friendly']
# Southwest Airlines
# ['This is total disappointment']
# ['They helped us resolve the issue']
# Spirit Airlines
# ['terrible all the way around']
# ['My experience was excellent']
# Suparna Airlines
# no negative reviews
# no positive reviews
# Sun-Air
# no negative reviews
# ['recommend this airline']
# Super Air Jet
# ['bad overall experience']
# ['gets high praise from me']
# Surinam Airways
# ['flight has delay for 6 hrs ']
# ['Overall the service was good']
# SunExpress
# ['I am utterly disappointed']
# ['I recommend the flight with SunExpress']
# T'Way Air
# ['unhappy with their service']
# ['I had a pleasant experience throughout']
# Jet2.com
# ['dreadful, delayed flights']
# ['brilliant from start to finish"\n']
# Sunwing Airlines
# ['worst experience ever']
# ['very pleasant and attentive']
# TACV Cabo Verde Airlines
# ['Avoid this airline at all costs']
# ["I'll definitely fly again"]
# TAAG Angola Airlines
# ['refused to refund it']
# ['attendants were friendly']
# TAG Airlines
# ['terrible customer service']
# ['Very friendly staff and crew']
# Tailwind Airlines
# no negative reviews
# ['staff were very friendly']
# Tame Línea Aérea Del Ecuador
# ['Would avoid if you can']
# no positive reviews
# TAR Aerolineas
# ['Worst flight company ever']
# ['Excellent service']
# TAME
# ['pathetic customer service']
# ['great customer service']
# TAM Airlines
# ['incompetent airline']
# ['friendly and acceptable']
# Swoop
# ['difficult to cancel flights']
# ['crew were very friendly']
# Swiss Intl Air Lines
# ['difficult to deal with']
# ['Free sandwich and chocolate bar']
# Thai AirAsia
# ['Very poor service']
# ['seat was fairly comfortable']
# TAROM Romanian
# ['unprofessional behaviour by Tarom']
# ['food was delicious']
# Thai Lion Air
# ['my $400 suitcase damaged']
# ['friendly air crew']
# Thomas Cook Airlines Scandinavia
# no negative reviews
# ['food was better than average']
# Tianjin Airlines
# ['avoid taking flights']
# ['Staff were great']
# TAP Portugal
# ['business class very uncomfortable']
# ['Was completely satisfied']
# Tibet Airlines
# no negative reviews
# ['would recommend Tibet Airlines']
# Thai Smile Airways
# ['worst airline in terms of customer service']
# ['Everything was delightful']
# Thomas Cook Airlines
# ['10 hours of agony']
# ['crew were genuinely friendly']
# Thomson Airways
# ["worst flight I've had"]
# ['the legroom was good']
# Tigerair Taiwan
# ['The worst experience']
# ['seamless and flawless flight']
# Thai Airways
# ['Such a disappointment']
# ['definitely recommend this airline']
# Tigerair
# ['their service to customers is unfair']
# ['ground staff polite and kind']
# Tigerair Australia
# ['expect me to pay for their error']
# ['crew were friendly and efficient']
# Tropic Air Belize
# ['This company is horrific']
# ['Great little airline']
# Trigana Air
# no negative reviews
# ['Aircraft was clean and cool']
# Titan Airways
# ['Absolutely dreadful']
# ['flight just like they used to be']
# Transaero Airlines
# ['delays without any reason']
# no positive reviews
# TUI Airways
# ['this company is the worst I ever seen']
# ['would happily fly with them again"\n']
# Transavia
# ['useless ordeal']
# ['Pleasant cabin crew']
# TUIfly Nordic
# no negative reviews
# no positive reviews
# Uganda Airlines
# ['one of the worst days of my life']
# ['a really pleasant experience']
# TUS Airways
# no negative reviews
# ['professional and friendly']
# Turkmenistan Airlines
# ['disappointed with the service ']
# ['Great Indian vegetarian food']
# TUIfly
# ['Just bad practices']
# ['if price is good I would fly them again']
# Tunisair
# ['worst airline I have ever travelled']
# ['crew were very friendly']
# Ukraine International
# ['worst company to fly']
# ['share my positive experience']
# UP by El Al
# no negative reviews
# ['seat comfort in Economy Plus good']
# US-Bangla Airlines
# ['very rude, very unprofessional']
# ['Staff were good']
# Ultra Air
# ['worst airline experience ever.']
# ['Nothing to complain about']
# Ural Airlines
# ['avoid it in the future']
# ['flight to Bishkek was nice and safe']
# US Airways
# ['absolutely the worst experience']
# ['nice meal service, friendly staff']
# ViaAir
# ['never recommend this airline']
# no positive reviews
# V Air
# ['delays and more delay']
# ['spotless, efficient, thoughtful']
# Vanilla Air
# ['the worst airline in Japan']
# ['staff were friendly and welcoming']
# Uzbekistan Airways
# ['seat cramped, cabin crew unfriendly']
# ['very attentive and pleasant staff']
# Vistara
# ['Vistara is seriously lacking']
# ['Really pleasant experience']
# VietJet Air
# ['discourage you to travel with them']
# ['in the air things are good']
# Vietnam Airlines
# ['ground staff were rude']
# ['amazing aircraft A350']
# VivaAerobús
# ['horrible and frustrating experience']
# ['professional and friendly']
# Virgin America
# ['complete lack of information']
# ['overall performance was great']
# Viva Air
# ['This is the worst airline']
# no positive reviews
# Virgin Atlantic
# ['misinformation and lack of planning']
# ['lacks the wow factor']
# VLM Airlines
# ['very poor customer service ']
# no positive reviews
# VivaColombia
# ['This is the worst airline']
# no positive reviews
# Virgin Australia
# ['ruthless, pathetic and condescending']
# ['staff efficient and warm']
# Voyage Air
# ['Complete Scam, rip off company']
# no positive reviews
# Volotea
# ['Avoid at any cost']
# ['satisfied with the quality of welcome on board']
# Wamos Air
# ['Worst flight of my life']
# ['staff were courteous and helpful']
# Volaris
# ['Avoid at all costs']
# ['I hope to be able to travel again']
# Turkish Airlines
# ['customer service is outrageous']
# ['pretty comfy seats']
# WestJet Airlines
# ['I will avoid at all costs in the future']
# ['they still have some room to improve']
# Vueling Airlines
# ['usual awful service']
# ['I enjoyed the short flight']
# United Airlines
# ['Terrible communication']
# ['regional jet was brilliant']
# World2Fly
# ['uncomfortable and unnecessary situation']
# no positive reviews
# Winair
# ['Winair is a terrible airline']
# no positive reviews
# Wings Air
# ['flight delayed for 2 hours']
# ['seats were reasonably comfortable']
# Wingo
# ['This is a poor airline"\n']
# ['offered excellent service']
# Wideroe
# ['complete waste of time']
# ['cabin crew were nice']
# Xiamen Airlines
# ['all unbelievably awful']
# ['polite and helpful cabin crew']
# Zambia Airways
# no negative reviews
# ['Nice staff, water served ad libitum']
# Yangon Airways
# no negative reviews
# ['All in all a good flight']
# Yeti Airlines
# ['Both the flights were delayed']
# ['cabin crew was friendly']
# Yakutia Airlines
# no negative reviews
# no positive reviews
# XL Airways France
# ['very low cost airline']
# ['attentive and very friendly']
# ZIPAIR
# ['Avoid at all costs']
# ['I highly recommend ZipAir']
# WOW air
# ['communication method was ridiculous']
# ['brilliant, efficient experience']
# Wizz Air
# ['I’m utterly shocked']
# ['Very attractive prices']

# %% [markdown]
# CREATION OF WORDCLOUDS

# %%
import pandas as pd
import numpy as np
import re
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS 
from PIL import Image

# %%
from nltk.corpus import stopwords

# %%
#do this per airline with most reviews having a nice sentiment analysis (1000+)

# %%
review_counts = sentimentdf.groupby('AIRLINENAME').size().reset_index(name='REVIEW_COUNT')

# Filter airlines with at least 10 reviews
airlines_with_max_reviews = review_counts[review_counts['REVIEW_COUNT'] >= 1000]['AIRLINENAME']

# %%
airlines_with_max_reviews
# Out:
# 78           American Airlines
# 121            British Airways
# 141    China Southern Airlines
# 157            Delta Air Lines
# 187          Frontier Airlines
# 330              Qatar Airways
# 385            Spirit Airlines
# 441            United Airlines
# Name: AIRLINENAME, dtype: object

# %%
wordcloud_df = sentimentdf[sentimentdf['AIRLINENAME'].isin(airlines_with_max_reviews)]

# %%
wordcloud_df.sample()
# Out:
#        Unnamed: 0      AIRLINENAME  CABINTYPE   DATEFLOWN            DATEPUB  \
# 23293       23371  British Airways          4  2016-02-01  2nd February 2016
#
#        ENTERTAINMENTRATING  FOODRATING  GROUNDSERVICERATING  ORIGINCOUNTRY  \
# 23293                    4           3                    3  UnitedKingdom
#
#        OVERALLSCORE  RECOMMENDED  \
# 23293             5            0
#
#                                                   REVIEW       ROUTE ORIGIN  \
# 23293  Thanks to a time change from 23.55 to 00.05, w...  GIG to LHR    GIG
#
#       DESTINY  SCALE_YN  SEATCOMFORTRATING  SERVICERATING             SLUG  \
# 23293     LHR         0                  3              4  british-airways
#
#                               TITLE  TRAVELLER  PURPOSE  TRIPVERIFIED  \
# 23293  not a first class experience          2        1             0
#
#        VALUERATING  WIFIRATING                             UNIQUE_ID  \
# 23293            3           0  adb0a5a7-9f64-4b7e-8f07-ce450ec2672e
#
#        LONGDISTANCE  YEAR                       TOKENIZREVIEW  \
# 23293             1  2016  [not, a, first, class, experience]
#
#               filtered_tokens                    TEXT  SENTIMENT  SENTPLUS
# 23293  first class experience  first class experience          0         1

# %%
#drop sentiments )0, they might be confusing
wordcloud_df=(wordcloud_df[wordcloud_df['SENTIMENT']!=0])

# %%
wordcloud_df.AIRLINENAME.value_counts()
# Out:
# AIRLINENAME
# American Airlines          2223
# United Airlines            1848
# Spirit Airlines            1562
# Frontier Airlines          1137
# China Southern Airlines    1068
# Delta Air Lines            1052
# British Airways             976
# Qatar Airways               919
# Name: count, dtype: int64

# %%
planes=wordcloud_df["TEXT"]
texto = " ".join(i for i in planes)
mask = np.array(Image.open("images/plane.png"))
stop_words = stopwrd

#add words that aren't in the NLTK stopwords list
new_stopwords = ['customer service','service', 'customer', 'review', 'airline', 'flight', 'seat']
new_stopwords_list = stopwrd.extend(new_stopwords)
 
wordcloud = WordCloud(stopwords=new_stopwords_list, background_color="black", max_words=80, mask=mask, colormap="Dark2", contour_width=1, contour_color="white").generate(texto)
plt.figure( figsize=(10,10))
plt.title("What do they say about the airline?", weight="bold", size=20, color="black")
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('images/plane_wc.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
stopwrd
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'and',
#  'I',
#  'A',
#  'And',
#  'So',
#  'arnt',
#  'This',
#  'When',
#  'It',
#  'many',
#  'Many',
#  'so',
#  'cant',
#  'again',
#  'Yes',
#  'yes',
#  'No',
#  'no',
#  'These',
#  'these',
#  'customer service',
#  'service',
#  'customer',
#  'review',
#  'customer review',
#  'airline',
#  'airlines',
#  'flight',
#  'seat',
#  'seats',
#  'seat',
#  'customer review',
#  '$',
#  '#',
#  '£',
#  'check-in',
#  'check in',
#  'fly',
#  'Philippine Airlines',
#  'Joon',
#  'Ariana Afghan Airlines',
#  'Lynx Air',
#  'Air Madagascar',
#  'Aegean Airlines',
#  'Jetstar Airways',
#  'Firefly',
#  'Pakistan Intl Airlines',
#  'AirAsia Zest',
#  'AnadoluJet',
#  'Passion Air',
#  'Egyptair',
#  'bmi Regional',
#  'Onur Air',
#  'MEGA Maldives Airlines',
#  'Thomas Cook Airlines',
#  'Evelop Airlines',
#  'Citilink',
#  'Copa Airlines',
#  'Transaero Airlines',
#  'Sunwing Airlines',
#  'Far Eastern Air Transport',
#  'QantasLink',
#  'Canaryfly',
#  'Aurigny Air',
#  'US-Bangla Airlines',
#  'Danish Air Transport',
#  'Rhein-Neckar Air',
#  'SkyWork Airlines',
#  'flydubai',
#  'TUS Airways',
#  'Air Juan',
#  'Israir Airlines',
#  'Pan Pacific Airlines',
#  'Iberia Express',
#  'Openskies',
#  'Southwest Airlines',
#  'Croatia Airlines',
#  'Go First',
#  'Aero VIP',
#  'Insel Air',
#  'Brussels Airlines',
#  'Kam Air',
#  'Mann Yadanarpon Airlines',
#  "T'Way Air",
#  'Dimonim Air',
#  'Air Tanzania',
#  'TUI Airways',
#  'Africa World Airlines',
#  'Peach Aviation',
#  'American Eagle',
#  'Kenya Airways',
#  'Ethiopian Airlines',
#  'ANA All Nippon Airways',
#  'Maya Island Air',
#  'Helvetic Airways',
#  'Malindo Air',
#  'Nature Air',
#  'Binter Canarias',
#  'Cebu Pacific',
#  'Spirit Airlines',
#  'SilkAir',
#  'Air Mauritius',
#  'Fiji Airways',
#  'Tibet Airlines',
#  'Maldivian',
#  'Solomon Airlines',
#  'Bangkok Airways',
#  'Air Greenland',
#  'Air Zimbabwe',
#  'Cambodia Angkor Air',
#  'AirAsia',
#  'Air KBZ',
#  'LIAT',
#  'Asiana Airlines',
#  'Arkefly',
#  'Air Canada',
#  'PenAir',
#  'Caribbean Airlines',
#  'Yangon Airways',
#  'Cathay Pacific Airways',
#  'Hainan Airlines',
#  'Auric Air',
#  'Ellinair',
#  'Vistara',
#  'Eastern Airways',
#  'Nile Air',
#  'Jordan Aviation',
#  'Bhutan Airlines',
#  'Royal Jordanian Airlines',
#  'Viva Air',
#  'ASKY Airlines',
#  'Safarilink',
#  'Japan Airlines',
#  'Novoair',
#  'SA Express',
#  'Mandarin Airlines',
#  'Norse Atlantic Airways',
#  'Privilege Style',
#  'Andes Líneas Aéreas',
#  'Precision Air',
#  'Bulgaria Air',
#  'Thomas Cook Airlines Scandinavia',
#  'Aigle Azur',
#  'Flair Airlines',
#  'HOP!',
#  'Condor Airlines',
#  'Manta Air',
#  'Jetblue Airways',
#  'Laudamotion',
#  'Salam Air',
#  'Air India',
#  'NAM Air',
#  'Georgian Airways',
#  'Rossiya Airlines',
#  'Tunisair',
#  'Cape Air',
#  'SVG Air',
#  'Cobalt',
#  'Red Wings Airlines',
#  'LAN Peru',
#  'TACA Airlines',
#  'Atlantic Airways',
#  'WestJet Airlines',
#  'Xiamen Airlines',
#  'Qantas Airways',
#  'Trigana Air',
#  'Frontier Airlines',
#  'Jetstar Asia',
#  'FlyArystan',
#  'Interjet',
#  'Emirates',
#  'Montenegro Airlines',
#  'Swiss Intl Air Lines',
#  'China Airlines',
#  'Armenia Air Company',
#  'SATA Air Azores',
#  'Air Nostrum',
#  'Felix Airways',
#  'AB Aviation',
#  'Volaris',
#  'flybe',
#  'Vanilla Air',
#  'PAL Express',
#  'Motor Sich Airlines',
#  'Finnair',
#  'Cubana Airlines',
#  'Aer Lingus',
#  'Air Italy',
#  'LAN Airlines',
#  'El Al Israel Airlines',
#  'Libyan Airlines',
#  'Mango Airlines',
#  'Air Costa',
#  'MAYAir',
#  'Jet Airways',
#  'Nordica',
#  'British Airways',
#  'Yeti Airlines',
#  'Korean Air',
#  'Intercaribbean Airways',
#  'Kan Air',
#  'Sichuan Airlines',
#  'Air France',
#  'Avior Airlines',
#  'UP by El Al',
#  'Air Djibouti',
#  'Sun Country Airlines',
#  'Air Namibia',
#  'Iran Air',
#  'Dragonair',
#  'Amaszonas',
#  'PAWA Dominicana',
#  'Swoop',
#  'Nauru Airlines',
#  'Cathay Dragon',
#  'LAN Colombia',
#  'TAR Aerolineas',
#  'Aeromexico',
#  'Smartavia',
#  'Madagasikara Airways',
#  'Darwin Airline',
#  'Royal Brunei Airlines',
#  'Azerbaijan Airlines',
#  'Blue Panorama Airlines',
#  'TAG Airlines',
#  'Avianca Ecuador',
#  'Thai Lion Air',
#  'FlySafair',
#  'airBaltic',
#  'Bamboo Airways',
#  'China Eastern Airlines',
#  'Wingo',
#  'SriLankan Airlines',
#  'Hi Fly',
#  'Buddha Air',
#  'Peruvian Airlines',
#  'Air Busan',
#  "Air Cote d'Ivoire",
#  'Titan Airways',
#  'Turkish Airlines',
#  'SmartWings',
#  'AirAsia India',
#  'Nordic Regional Airlines',
#  'Air China',
#  'Mahan Air',
#  'Jetstar Japan',
#  'American Airlines',
#  'HK Express',
#  'Badr Airlines',
#  "Air North Yukon's Airline",
#  'Edelweiss Air',
#  'Corendon Airlines',
#  'Sun-Air',
#  'South African Airways',
#  'Star Peru',
#  'Bassaka Air',
#  'Germania Airline',
#  'Regional Express',
#  'Air New Zealand',
#  'Island Air',
#  'Cambodia Bayon Airlines',
#  'ITA Airways',
#  'NordStar',
#  'Pegasus Airlines',
#  'Zambia Airways',
#  'Horizon Air',
#  'Blu-express',
#  'Sky Airline',
#  'Passaredo',
#  'Wings Air',
#  'EVA Air',
#  'Tigerair Australia',
#  'TAAG Angola Airlines',
#  'BA CityFlyer',
#  'Suparna Airlines',
#  'Cambodia Airways',
#  'Aircalin',
#  'Surinam Airways',
#  'Akasa Air',
#  'Blue Air',
#  'LC Perú',
#  'Air Seychelles',
#  'Transavia',
#  'Beijing Capital Airlines',
#  'Eurowings',
#  'Garuda Indonesia',
#  'Skybus',
#  'Gol Transportes Aéreos',
#  'AirAsia Philippines',
#  'Greater Bay Airlines',
#  'AirSWIFT',
#  'Lufthansa',
#  'Hawaiian Airlines',
#  'Skytrans Airlines',
#  'Jin Air',
#  'Azul Airlines',
#  'AirAsia X',
#  'TAP Portugal',
#  'Golden Myanmar Airlines',
#  'Wizz Air',
#  'Vietnam Airlines',
#  'Air Pegasus',
#  'Ural Airlines',
#  'US Airways',
#  'Iran Aseman Airlines',
#  'Kish Airlines',
#  'CityJet',
#  'Ukraine International',
#  'Aerolineas Argentinas',
#  'Silver Airways',
#  'United Airlines',
#  'Wamos Air',
#  'SereneAir',
#  'BH Air',
#  'LOT Polish Airlines',
#  'euroAtlantic Airways',
#  'Hunnu Air',
#  'Boliviana de Aviacion',
#  'Iberia',
#  'Jeju Air',
#  'Regent Airways',
#  'Air Arabia',
#  'Atlasglobal',
#  'Himalaya Airlines',
#  'TUIfly Nordic',
#  'Oman Air',
#  'Batik Air',
#  'SATENA',
#  'Thai Smile Airways',
#  'Alaska Airlines',
#  'Santa Barbara Airlines',
#  'Seaborne Airlines',
#  'Air Malta',
#  'Wideroe',
#  'Cyprus Airways',
#  'Tame Línea Aérea Del Ecuador',
#  'Freebird Airlines',
#  'Tigerair',
#  'Nok Air',
#  'HiSky',
#  'Druk Air',
#  'GoAir',
#  'Comair',
#  'Corsair',
#  'TAROM Romanian',
#  'Primera Air',
#  'VivaAerobús',
#  'S7 Siberia Airlines',
#  'Mauritania Airlines',
#  'Malawian Airlines',
#  'Tropic Air Belize',
#  'Safi Airways',
#  'VietJet Air',
#  'Volotea',
#  'Aeromar',
#  'ViaAir',
#  'Saudi Arabian Airlines',
#  'Skymark Airlines',
#  'VivaColombia',
#  'Boutique Air',
#  'SkyUp Airlines',
#  'TUIfly',
#  'ZIPAIR',
#  'Nordwind Airlines',
#  'Porter Airlines',
#  'China United Airlines',
#  'FMI Air',
#  'Virgin Atlantic',
#  'Juneyao Airlines',
#  'Jetairfly',
#  'Virgin Australia',
#  'XL Airways France',
#  'Germanwings',
#  'Olympic Air',
#  'Lion Air',
#  'Air Koryo',
#  'Canadian North',
#  'Scoot',
#  'Utair Aviation',
#  'VLM Airlines',
#  'Mihin Lanka',
#  'JetSmart',
#  'SCAT Airlines',
#  'Small Planet Airlines',
#  'Air Corsica',
#  'Qazaq Air',
#  'Pobeda Airlines',
#  'SkyWest Airlines',
#  'Winair',
#  'China Southern Airlines',
#  'Estonian Air',
#  'Uganda Airlines',
#  'Avelo Airlines',
#  'IndiGo',
#  'Somon Air',
#  'Etihad Airways',
#  'Lubeck Air',
#  'NokScoot',
#  'SATA International',
#  'Sky Express Airlines',
#  'Alliance Air',
#  'Middle East Airlines',
#  'Air Algerie',
#  'Shandong Airlines',
#  'TACV Cabo Verde Airlines',
#  'Shenzhen Airlines',
#  'WOW air',
#  'Voyage Air',
#  'Turkmenistan Airlines',
#  'Dynamic International Airways',
#  'Thai Airways',
#  'Breeze Airways',
#  'Air Vanuatu',
#  'Central Mountain Air',
#  'BoraJet',
#  'Petroleum Air Services',
#  'Jetstar Pacific',
#  'Spring Airlines',
#  'Pacific Airlines',
#  'Air Dolomiti',
#  'Kuwait Airways',
#  'Lao Airlines',
#  'Air Caraibes',
#  'MIAT Mongolian Airlines',
#  'Delta Air Lines',
#  'Avianca Brazil',
#  'Uzbekistan Airways',
#  'Hong Kong Airlines',
#  'Air Berlin',
#  'Air Botswana',
#  'Royal Air Maroc',
#  'Monarch Airlines',
#  'Kulula',
#  'Thomas Cook Airlines Belgium',
#  'World2Fly',
#  'Virgin America',
#  'Adria Airways',
#  'Air Iceland Connect',
#  'V Air',
#  'Easyfly',
#  'KLM Royal Dutch Airlines',
#  'Air Astana',
#  'fastjet',
#  'TAME',
#  'Air Serbia',
#  'Tigerair Taiwan',
#  'SAS Scandinavian',
#  'Air Macau',
#  'Super Air Jet',
#  'French Bee',
#  'Air Moldova',
#  'JetsuiteX',
#  'Air Austral',
#  'Fly540.com',
#  'Austrian Airlines',
#  'SunExpress',
#  'Air Burkina',
#  'Singapore Airlines',
#  'Yakutia Airlines',
#  'Arik Air',
#  'Air Tahiti Nui',
#  'Airlink',
#  'Allegiant Air',
#  'Lao Skyway',
#  'Sriwijaya Air',
#  'Jazeera Airways',
#  'Ravn Alaska',
#  'Thai AirAsia',
#  'StarFlyer',
#  'Biman Bangladesh Airlines',
#  'Orient Thai Airlines',
#  'SpiceJet',
#  'EWA Air',
#  'Meridiana',
#  'Air Niugini',
#  'LATAM Airlines',
#  'Air Transat',
#  'easyJet',
#  'ATA Airlines',
#  'Air Canada rouge',
#  'Azur Air Germany',
#  'Jet2.com',
#  'Level',
#  'Omni Air International',
#  'Qatar Airways',
#  'CemAir',
#  'JC International Airlines',
#  'Air Cairo',
#  'Eastern Airlines',
#  'Air Europa',
#  'Alitalia',
#  'Lucky Air',
#  'Bluebird Airways',
#  'Coastal Aviation',
#  'Icelandair',
#  'Nouvelair',
#  'Shaheen Air',
#  'Ernest Airlines',
#  'Tailwind Airlines',
#  'Buta Airways',
#  'SmartLynx Airlines',
#  'Jazz',
#  'Myanmar Airways',
#  'Rex Airlines',
#  'Air Antilles',
#  'AeroItalia',
#  'Nepal Airlines',
#  'Grand Cru Airlines',
#  'Luxair',
#  'Loganair',
#  'Air Rarotonga',
#  'FLYONE',
#  'Norwegian',
#  'Vueling Airlines',
#  'Blue1',
#  'Cayman Airways',
#  'Belavia',
#  'Ryanair',
#  'Ultra Air',
#  'Aeroflot Russian Airlines',
#  'LAM Mozambique',
#  'PLAY',
#  'Flynas',
#  'Mokulele Airlines',
#  'Myanmar National Airlines',
#  'Bahamasair',
#  'Airnorth',
#  'Tianjin Airlines',
#  'airblue',
#  'TAM Airlines',
#  'flyadeal',
#  'KD Air',
#  'Sansa Airlines',
#  'Eastar Jet',
#  'Nordavia',
#  'Camair-Co',
#  'Blue Islands',
#  'Mack Air',
#  'Rwandair',
#  'La Compagnie',
#  'Air Panama',
#  'Arkia Israeli Airlines',
#  'Air India Express',
#  'CSA Czech Airlines',
#  'Malaysia Airlines',
#  'Thomson Airways',
#  'Avianca',
#  'Alliance Airlines',
#  'Shanghai Airlines',
#  'Iraqi Airways',
#  'NIKI',
#  'Gulf Air',
#  'Philippine Airlines',
#  'Joon',
#  'Ariana Afghan Airlines',
#  'Lynx Air',
#  'Air Madagascar',
#  'Aegean Airlines',
#  'Jetstar Airways',
#  'Firefly',
#  'Pakistan Intl Airlines',
#  'AirAsia Zest',
#  'AnadoluJet',
#  'Passion Air',
#  'Egyptair',
#  'bmi Regional',
#  'Onur Air',
#  'MEGA Maldives Airlines',
#  'Thomas Cook Airlines',
#  'Evelop Airlines',
#  'Citilink',
#  'Copa Airlines',
#  'Transaero Airlines',
#  'Sunwing Airlines',
#  'Far Eastern Air Transport',
#  'QantasLink',
#  'Canaryfly',
#  'Aurigny Air',
#  'US-Bangla Airlines',
#  'Danish Air Transport',
#  'Rhein-Neckar Air',
#  'SkyWork Airlines',
#  'flydubai',
#  'TUS Airways',
#  'Air Juan',
#  'Israir Airlines',
#  'Pan Pacific Airlines',
#  'Iberia Express',
#  'Openskies',
#  'Southwest Airlines',
#  'Croatia Airlines',
#  'Go First',
#  'Aero VIP',
#  'Insel Air',
#  'Brussels Airlines',
#  'Kam Air',
#  'Mann Yadanarpon Airlines',
#  "T'Way Air",
#  'Dimonim Air',
#  'Air Tanzania',
#  'TUI Airways',
#  'Africa World Airlines',
#  'Peach Aviation',
#  'American Eagle',
#  'Kenya Airways',
#  'Ethiopian Airlines',
#  'ANA All Nippon Airways',
#  'Maya Island Air',
#  'Helvetic Airways',
#  'Malindo Air',
#  'Nature Air',
#  'Binter Canarias',
#  'Cebu Pacific',
#  'Spirit Airlines',
#  'SilkAir',
#  'Air Mauritius',
#  'Fiji Airways',
#  'Tibet Airlines',
#  'Maldivian',
#  'Solomon Airlines',
#  'Bangkok Airways',
#  'Air Greenland',
#  'Air Zimbabwe',
#  'Cambodia Angkor Air',
#  'AirAsia',
#  'Air KBZ',
#  'LIAT',
#  'Asiana Airlines',
#  'Arkefly',
#  'Air Canada',
#  'PenAir',
#  'Caribbean Airlines',
#  'Yangon Airways',
#  'Cathay Pacific Airways',
#  'Hainan Airlines',
#  'Auric Air',
#  'Ellinair',
#  'Vistara',
#  'Eastern Airways',
#  'Nile Air',
#  'Jordan Aviation',
#  'Bhutan Airlines',
#  'Royal Jordanian Airlines',
#  'Viva Air',
#  'ASKY Airlines',
#  'Safarilink',
#  'Japan Airlines',
#  'Novoair',
#  'SA Express',
#  'Mandarin Airlines',
#  'Norse Atlantic Airways',
#  'Privilege Style',
#  'Andes Líneas Aéreas',
#  'Precision Air',
#  'Bulgaria Air',
#  'Thomas Cook Airlines Scandinavia',
#  'Aigle Azur',
#  'Flair Airlines',
#  'HOP!',
#  'Condor Airlines',
#  'Manta Air',
#  'Jetblue Airways',
#  'Laudamotion',
#  'Salam Air',
#  'Air India',
#  'NAM Air',
#  'Georgian Airways',
#  'Rossiya Airlines',
#  'Tunisair',
#  'Cape Air',
#  'SVG Air',
#  'Cobalt',
#  'Red Wings Airlines',
#  'LAN Peru',
#  'TACA Airlines',
#  'Atlantic Airways',
#  'WestJet Airlines',
#  'Xiamen Airlines',
#  'Qantas Airways',
#  'Trigana Air',
#  'Frontier Airlines',
#  'Jetstar Asia',
#  'FlyArystan',
#  'Interjet',
#  'Emirates',
#  'Montenegro Airlines',
#  'Swiss Intl Air Lines',
#  'China Airlines',
#  'Armenia Air Company',
#  'SATA Air Azores',
#  'Air Nostrum',
#  'Felix Airways',
#  'AB Aviation',
#  'Volaris',
#  'flybe',
#  'Vanilla Air',
#  'PAL Express',
#  'Motor Sich Airlines',
#  'Finnair',
#  'Cubana Airlines',
#  'Aer Lingus',
#  'Air Italy',
#  'LAN Airlines',
#  'El Al Israel Airlines',
#  'Libyan Airlines',
#  'Mango Airlines',
#  'Air Costa',
#  'MAYAir',
#  'Jet Airways',
#  'Nordica',
#  'British Airways',
#  'Yeti Airlines',
#  'Korean Air',
#  'Intercaribbean Airways',
#  'Kan Air',
#  'Sichuan Airlines',
#  'Air France',
#  'Avior Airlines',
#  'UP by El Al',
#  'Air Djibouti',
#  'Sun Country Airlines',
#  'Air Namibia',
#  'Iran Air',
#  'Dragonair',
#  'Amaszonas',
#  'PAWA Dominicana',
#  'Swoop',
#  'Nauru Airlines',
#  'Cathay Dragon',
#  'LAN Colombia',
#  'TAR Aerolineas',
#  'Aeromexico',
#  'Smartavia',
#  'Madagasikara Airways',
#  'Darwin Airline',
#  'Royal Brunei Airlines',
#  'Azerbaijan Airlines',
#  'Blue Panorama Airlines',
#  'TAG Airlines',
#  'Avianca Ecuador',
#  'Thai Lion Air',
#  'FlySafair',
#  'airBaltic',
#  'Bamboo Airways',
#  'China Eastern Airlines',
#  'Wingo',
#  'SriLankan Airlines',
#  'Hi Fly',
#  'Buddha Air',
#  'Peruvian Airlines',
#  'Air Busan',
#  "Air Cote d'Ivoire",
#  'Titan Airways',
#  'Turkish Airlines',
#  'SmartWings',
#  'AirAsia India',
#  'Nordic Regional Airlines',
#  'Air China',
#  'Mahan Air',
#  'Jetstar Japan',
#  'American Airlines',
#  'HK Express',
#  'Badr Airlines',
#  "Air North Yukon's Airline",
#  'Edelweiss Air',
#  'Corendon Airlines',
#  'Sun-Air',
#  'South African Airways',
#  'Star Peru',
#  'Bassaka Air',
#  'Germania Airline',
#  'Regional Express',
#  'Air New Zealand',
#  'Island Air',
#  'Cambodia Bayon Airlines',
#  'ITA Airways',
#  'NordStar',
#  'Pegasus Airlines',
#  'Zambia Airways',
#  'Horizon Air',
#  'Blu-express',
#  'Sky Airline',
#  'Passaredo',
#  'Wings Air',
#  'EVA Air',
#  'Tigerair Australia',
#  'TAAG Angola Airlines',
#  'BA CityFlyer',
#  'Suparna Airlines',
#  'Cambodia Airways',
#  'Aircalin',
#  'Surinam Airways',
#  'Akasa Air',
#  'Blue Air',
#  'LC Perú',
#  'Air Seychelles',
#  'Transavia',
#  'Beijing Capital Airlines',
#  'Eurowings',
#  'Garuda Indonesia',
#  'Skybus',
#  'Gol Transportes Aéreos',
#  'AirAsia Philippines',
#  'Greater Bay Airlines',
#  'AirSWIFT',
#  'Lufthansa',
#  'Hawaiian Airlines',
#  'Skytrans Airlines',
#  'Jin Air',
#  'Azul Airlines',
#  'AirAsia X',
#  'TAP Portugal',
#  'Golden Myanmar Airlines',
#  'Wizz Air',
#  'Vietnam Airlines',
#  'Air Pegasus',
#  'Ural Airlines',
#  'US Airways',
#  'Iran Aseman Airlines',
#  'Kish Airlines',
#  'CityJet',
#  ...]

# %%
for i in wordcloud_df.AIRLINENAME.unique():
    aerolinea=wordcloud_df[wordcloud_df.AIRLINENAME==i]
    planes=aerolinea["TEXT"]
    texto = " ".join(i for i in planes)
    mask = np.array(Image.open("images/plane.png"))
    stop_words = stopwrd

    #add words that aren't in the NLTK stopwords list
    new_stopwords = ['customer service','service', 'customer', 'review', 'airline', 'flight', 'seat', 'experience', 'BA', 'Delta', 'United', 'China', 'American', 'Frontier', 'British', 'Qatar', 'Spirit', 'Air Lines', 'Airlines', 'Airways']
    new_stopwords_list = stopwrd + new_stopwords +airline_stopwords
    
    wordcloud = WordCloud(stopwords=new_stopwords_list, background_color="black", max_words=200, mask=mask, colormap="Dark2", contour_width=1, contour_color="white").generate(texto)
    plt.figure( figsize=(10,10))
    plt.title(f"What do they say about {i}?", weight="bold", size=20, color="black")
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.savefig(f'images/plane_{i}_wc.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# https://tenor.com/es/view/rabbids-terrorism-jorts-jet-engine-rabbids-go-home-gif-19797468

# %% [markdown]
# https://tenor.com/es/view/plane-fall-falling-sit-scared-gif-11782294
